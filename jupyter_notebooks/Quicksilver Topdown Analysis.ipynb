# %%
import pandas as pd

pd.set_option("display.max_colwidth",999)

# %% [markdown]
# # Load Caliper JSON Data
# Drop data with empty function annotations and split function nestings into tuples "main/foo/bar" -> (main, foo, bar)

# %%
# Large files (>1gb) should be read in 1000 lines at a time and concatenated together, like so:
df = pd.concat(
    pd.read_json('quicksilver_topdown_counters.json', orient='records', lines=True, chunksize=1000)
)
df = df.dropna(subset=['function'])
df['function'] = df['function'].transform(lambda l: tuple(l.split('/')))
df.head()
# Out:
#     cali.caliper.version  cali.event.begin  cali.event.end  cali.event.set  \
# 114            1.7.0-dev             334.0             NaN             NaN
# 115            1.7.0-dev               NaN           334.0             NaN
# 117            1.7.0-dev             334.0             NaN             NaN
# 119            1.7.0-dev             334.0             NaN             NaN
# 120            1.7.0-dev               NaN           334.0             NaN
#
#     event.begin#function event.end#function  event.set#pthread.id  \
# 114             isInside                NaN                   NaN
# 115                  NaN           SumTasks                   NaN
# 117             collapse                NaN                   NaN
# 119             collapse                NaN                   NaN
# 120                  NaN           isInside                   NaN
#
#                                                         function  \
# 114            (main, initMC, initMesh, MC_Domain, findMaterial)
# 115                              (main, cycleTracking, SumTasks)
# 117                                        (main, cycleTracking)
# 119                                        (main, cycleTracking)
# 120  (main, initMC, initMesh, MC_Domain, findMaterial, isInside)
#
#      libpfm.counter.BR_MISP_RETIRED:ALL_BRANCHES  \
# 114                                            0
# 115                                            0
# 117                                            0
# 119                                         1005
# 120                                            0
#
#      libpfm.counter.CPU_CLK_UNHALTED:THREAD_P     ...       \
# 114                                         0     ...
# 115                                         0     ...
# 117                                         0     ...
# 119                                  13128535     ...
# 120                                         0     ...
#
#      libpfm.counter.RS_EVENTS:EMPTY_CYCLES  \
# 114                                      0
# 115                                   4915
# 117                                      0
# 119                                 788101
# 120                                      0
#
#      libpfm.counter.UOPS_EXECUTED:CORE_CYCLES_GE_1  \
# 114                                              0
# 115                                              0
# 117                                              0
# 119                                        9250136
# 120                                              0
#
#      libpfm.counter.UOPS_EXECUTED:CORE_CYCLES_GE_2  \
# 114                                              0
# 115                                              0
# 117                                              0
# 119                                        7512747
# 120                                              0
#
#      libpfm.counter.UOPS_EXECUTED:THREAD  libpfm.counter.UOPS_ISSUED:ANY  \
# 114                                    0                               0
# 115                               112918                               0
# 117                                    0                               0
# 119                             24753559                        29415199
# 120                                    0                               0
#
#      libpfm.counter.UOPS_RETIRED:RETIRE_SLOTS  mpi.rank  mpi.size  \
# 114                                         0      10.0      16.0
# 115                                         0       1.0      16.0
# 117                                         0       0.0      16.0
# 119                                  29398111       1.0      16.0
# 120                                         0      10.0      16.0
#
#      time.inclusive.duration  time.offset
# 114                      NaN      2813734
# 115                     17.0     32336221
# 117                      NaN     29924061
# 119                      NaN     32380275
# 120                     21.0      2813755
#
# [5 rows x 31 columns]

# %% [markdown]
# # Perform inclusive aggregation (derive the "call tree")
#
# Specify inclusive aggregators, just sum up all the libpfm counters, time, and get a count of a constant string

# %%
import hatchet

# %%
aggregators = dict([ (c, 'sum') for c in filter(lambda col: 'libpfm' in col, df.columns)])
aggregators['time.inclusive.duration'] = 'max'
aggregators['cali.caliper.version'] = 'count'
aggregators
# Out:
# {'cali.caliper.version': 'count',
#  'libpfm.counter.BR_MISP_RETIRED:ALL_BRANCHES': 'sum',
#  'libpfm.counter.CPU_CLK_UNHALTED:THREAD_P': 'sum',
#  'libpfm.counter.CYCLE_ACTIVITY:CYCLES_NO_EXECUTE': 'sum',
#  'libpfm.counter.CYCLE_ACTIVITY:STALLS_L1D_PENDING': 'sum',
#  'libpfm.counter.CYCLE_ACTIVITY:STALLS_L2_PENDING': 'sum',
#  'libpfm.counter.CYCLE_ACTIVITY:STALLS_LDM_PENDING': 'sum',
#  'libpfm.counter.IDQ:MS_UOPS': 'sum',
#  'libpfm.counter.IDQ_UOPS_NOT_DELIVERED:CORE': 'sum',
#  'libpfm.counter.INT_MISC:RECOVERY_CYCLES': 'sum',
#  'libpfm.counter.MACHINE_CLEARS:COUNT': 'sum',
#  'libpfm.counter.MEM_LOAD_UOPS_RETIRED:L3_HIT': 'sum',
#  'libpfm.counter.MEM_LOAD_UOPS_RETIRED:L3_MISS': 'sum',
#  'libpfm.counter.RESOURCE_STALLS:SB': 'sum',
#  'libpfm.counter.RS_EVENTS:EMPTY_CYCLES': 'sum',
#  'libpfm.counter.UOPS_EXECUTED:CORE_CYCLES_GE_1': 'sum',
#  'libpfm.counter.UOPS_EXECUTED:CORE_CYCLES_GE_2': 'sum',
#  'libpfm.counter.UOPS_EXECUTED:THREAD': 'sum',
#  'libpfm.counter.UOPS_ISSUED:ANY': 'sum',
#  'libpfm.counter.UOPS_RETIRED:RETIRE_SLOTS': 'sum',
#  'time.inclusive.duration': 'max'}

# %%
mrt = hatchet.MultiRootTree.from_samples(df, 'function', aggregators)
mrt.df_nodes
# Out:
#           hash#function  libpfm.counter.BR_MISP_RETIRED:ALL_BRANCHES  \
# 71  2574226508381785094                                       331092
# 15 -7252534472619379718                                       330788
# 30 -3677243502532151653                                       231806
# 47  -927934058046326774                                       274511
# 85  5331452723580995626                                      1023251
# 90  5955584031965748850                                       108486
# 23 -4933507252616422133                                      2052622
# 25 -4134057073213068368                                         2210
# 36 -2901336579335736432                                       330593
# 54  -376670115672843596                                         1608
# 59  1290044161575942532                                      1533724
# 69  3137460780166019260                                         1629
# 78  4443938504809891159                                       118048
# 2  -8885906963766464142                                        20838
# 14 -7264013457032837659                                      1410305
# 47  -572252942354143546                                         8933
# 63  2905914891805626554                                        88580
# 74  4964793335720556777                                        52676
# 81  6957787860313903023                                      4900113
# 83  7959062406079742903                                       716740
# 1  -8973096192519033624                                          334
# 7  -8376760555805231436                                           38
# 29 -3346546285056646112                                      3158018
# 37 -1834282723900083241                                           37
# 39 -1329505548080475541                                        78528
# 43  -705510571855917191                                       240922
# 54  1578644897819887607                                        25945
# 58  1824199118260379446                                      5880314
# 61  3226576455897967531                                        86068
# 63  3768386929182066311                                        51577
# ..                  ...                                          ...
# 23  -788602314893872686                                          756
# 25  -515489496254773016                                         1007
# 28  1327647275769230351                                            0
# 29  1684812234173510571                                         1496
# 30  3152381168709113512                                       108930
# 33  3974207558341453912                                           52
# 34  4399659537923052962                                         1543
# 36  4948303505321721652                                          829
# 38  5561175753082870147                                       912083
# 39  5810354523748618040                                         4150
# 40  6392707864436864065                                        45366
# 41  8012283347977419031                                         2688
# 43  8605958245948087580                                          263
# 44  8826531664285963129                                     10153846
# 45  8886119691787648251                                         8007
# 0  -8404990865778211590                                          136
# 1  -7516306253691115888                                         3124
# 2  -5143781023991094254                                         3186
# 3  -3675806031077117392                                         2822
# 4  -3660262160707739778                                          124
# 5  -2281267291879510595                                         1693
# 6   -611320776416371186                                     10202805
# 7    646242863799796493                                         1886
# 9   3566080296536805615                                         1996
# 10  3947555474804788133                                        28034
# 11  4465666093020475086                                       160365
# 12  5362067455521828759                                        36416
# 13  8375893045446190810                                     79775648
# 14  9031087567878469606                                      1603823
# 0   1128851083484916900                                     92624367
#
#     libpfm.counter.CPU_CLK_UNHALTED:THREAD_P  \
# 71                                 939095615
# 15                                 868687790
# 30                                 651473871
# 47                                 865696693
# 85                                2821205312
# 90                                 290137977
# 23                                5717995979
# 25                                   4051803
# 36                                 871066201
# 54                                    731270
# 59                                4339736492
# 69                                   4015042
# 78                                 291322155
# 2                                    9633523
# 14                                5148550960
# 47                                  20071763
# 63                                 212671329
# 74                                1848761359
# 81                               13620683753
# 83                                 247987652
# 1                                     754097
# 7                                      94321
# 29                               10313272945
# 37                                     95127
# 39                                 215319238
# 43                                 638401654
# 54                                  17798031
# 58                               14413073721
# 61                                1851547507
# 63                                 110678292
# ..                                       ...
# 23                                   1691978
# 25                                   4979192
# 28                                         0
# 29                                    583514
# 30                                 222237092
# 33                                     58956
# 34                                   3598375
# 36                                   2544313
# 38                                1736776702
# 39                                   9157365
# 40                                  30878437
# 41                                    666272
# 43                                    673213
# 44                               28403304731
# 45                                  42226477
# 0                                     296077
# 1                                    1670919
# 2                                    5635312
# 3                                     967028
# 4                                     292244
# 5                                    3825388
# 6                                28485447524
# 7                                    1546319
# 9                                   10141701
# 10                                  70478621
# 11                                 269154003
# 12                                 161807562
# 13                               62002133193
# 14                                1704668742
# 0                                94986285197
#
#     libpfm.counter.CYCLE_ACTIVITY:CYCLES_NO_EXECUTE  \
# 71                                        202732865
# 15                                        188080918
# 30                                        140542409
# 47                                        187186353
# 85                                        611075227
# 90                                         62718156
# 23                                       1239343961
# 25                                           865255
# 36                                        189094567
# 54                                           133243
# 59                                        940949043
# 69                                           830135
# 78                                         63227540
# 2                                           1078962
# 14                                       1124508032
# 47                                          4224723
# 63                                         45964040
# 74                                        543220047
# 81                                       2958279482
# 83                                         66212809
# 1                                            109692
# 7                                              9925
# 29                                       2266217525
# 37                                            10325
# 39                                         47212433
# 43                                        138089250
# 54                                          2200520
# 58                                       3149129748
# 61                                        543834344
# 63                                          3409706
# ..                                              ...
# 23                                           484603
# 25                                          1474615
# 28                                           137658
# 29                                           192131
# 30                                         63408683
# 33                                            13501
# 34                                          1425677
# 36                                           843390
# 38                                        554428350
# 39                                          1474943
# 40                                          3468194
# 41                                           216466
# 43                                            77905
# 44                                       6383110182
# 45                                         38812879
# 0                                            399379
# 1                                           1446774
# 2                                           2007545
# 3                                            432909
# 4                                             74327
# 5                                           1513297
# 6                                        6439340748
# 7                                           1221205
# 9                                           3014742
# 10                                         16035228
# 11                                         26660339
# 12                                         44149506
# 13                                      18168324729
# 14                                        458481545
# 0                                       25640784027
#
#     libpfm.counter.CYCLE_ACTIVITY:STALLS_L1D_PENDING  \
# 71                                           5996515
# 15                                           5941646
# 30                                           4029885
# 47                                           5787708
# 85                                          18581459
# 90                                           1995205
# 23                                          37761611
# 25                                             31075
# 36                                           6167557
# 54                                             30963
# 59                                          29629585
# 69                                             20567
# 78                                           2089833
# 2                                              53408
# 14                                          40754268
# 47                                            129473
# 63                                           1429089
# 74                                            424658
# 81                                          94234664
# 83                                           9035039
# 1                                               1262
# 7                                                183
# 29                                          92613321
# 37                                               395
# 39                                           1991627
# 43                                           4425311
# 54                                            110533
# 58                                         111414877
# 61                                            627976
# 63                                            968634
# ..                                               ...
# 23                                             93150
# 25                                             65778
# 28                                             29419
# 29                                             34828
# 30                                          13789827
# 33                                                 0
# 34                                             48212
# 36                                             38750
# 38                                         179000440
# 39                                             35993
# 40                                           1037033
# 41                                             34586
# 43                                              3962
# 44                                         225613104
# 45                                           2898877
# 0                                              86581
# 1                                            1008331
# 2                                             189088
# 3                                             113651
# 4                                               2441
# 5                                              83306
# 6                                          229565499
# 7                                             476595
# 9                                             126448
# 10                                            682604
# 11                                           5046556
# 12                                           1222290
# 13                                        2103311591
# 14                                          11572603
# 0                                         2426610374
#
#     libpfm.counter.CYCLE_ACTIVITY:STALLS_L2_PENDING  \
# 71                                          2133947
# 15                                          2261905
# 30                                          1356632
# 47                                          2178189
# 85                                          6646584
# 90                                           677147
# 23                                         13663767
# 25                                             4719
# 36                                          2336499
# 54                                            31469
# 59                                         10979338
# 69                                             1818
# 78                                           802694
# 2                                             22746
# 14                                         12126220
# 47                                            22318
# 63                                           480046
# 74                                           433807
# 81                                         35466681
# 83                                          6432503
# 1                                               200
# 7                                                 0
# 29                                         36816794
# 37                                                0
# 39                                           906174
# 43                                          1520785
# 54                                            48455
# 58                                         46856044
# 61                                           673024
# 63                                           834333
# ..                                              ...
# 23                                            74001
# 25                                            30953
# 28                                            26165
# 29                                            26127
# 30                                         10406426
# 33                                                0
# 34                                            46015
# 36                                            18036
# 38                                        142508225
# 39                                             8378
# 40                                           972414
# 41                                            26897
# 43                                                0
# 44                                         94932787
# 45                                          3618631
# 0                                             79053
# 1                                            888415
# 2                                            135612
# 3                                            132513
# 4                                               748
# 5                                             79124
# 6                                          99346191
# 7                                            684979
# 9                                             57949
# 10                                           350488
# 11                                          4199986
# 12                                          1229646
# 13                                       1875672169
# 14                                          9836817
# 0                                        2056375245
#
#     libpfm.counter.CYCLE_ACTIVITY:STALLS_LDM_PENDING  \
# 71                                         104700838
# 15                                          97646291
# 30                                          72612542
# 47                                          97014114
# 85                                         316099320
# 90                                          32390107
# 23                                         641344694
# 25                                             98598
# 36                                          98017297
# 54                                                 0
# 59                                         487632002
# 69                                             92329
# 78                                          32768091
# 2                                              70303
# 14                                         587826048
# 47                                            494038
# 63                                          23634850
# 74                                         315013839
# 81                                        1532373398
# 83                                          38123089
# 1                                                  0
# 7                                                  0
# 29                                        1195274783
# 37                                                 0
# 39                                          24809623
# 43                                          71342411
# 54                                            120008
# 58                                        1634936206
# 61                                         316254962
# 63                                           2025808
# ..                                               ...
# 23                                            380597
# 25                                            837931
# 28                                             81081
# 29                                            101169
# 30                                          39937539
# 33                                                 0
# 34                                           1250091
# 36                                            330040
# 38                                         405224747
# 39                                                 0
# 40                                           2617933
# 41                                            113454
# 43                                             14590
# 44                                        3354856437
# 45                                          30352418
# 0                                             228034
# 1                                            2154584
# 2                                             801688
# 3                                              34677
# 4                                              45391
# 5                                            1346417
# 6                                         3388924971
# 7                                             963293
# 9                                            1708580
# 10                                           7456189
# 11                                          19700100
# 12                                          24123518
# 13                                       11497858560
# 14                                         287313219
# 0                                        15525923658
#
#     libpfm.counter.IDQ:MS_UOPS  libpfm.counter.IDQ_UOPS_NOT_DELIVERED:CORE  \
# 71                   188604576                                   567870734
# 15                   173545665                                   525449352
# 30                   130593947                                   392226689
# 47                   173483056                                   518288933
# 85                   565760476                                  1714789518
# 90                    57970771                                   175257073
# 23                  1145743325                                  3471473892
# 25                      123880                                       85830
# 36                   173970200                                   531231548
# 54                           0                                           0
# 59                   867295530                                  2627386312
# 69                      123027                                       84453
# 78                    58009253                                   178001910
# 2                        32890                                      664278
# 14                  1028915509                                  3050612392
# 47                      613629                                      453586
# 63                    42635343                                   128552014
# 74                   595369025                                   183752254
# 81                  2723119657                                  8276769092
# 83                    43605576                                   166197045
# 1                        28481                                      236409
# 7                        10216                                       34615
# 29                  2058042430                                  6166813668
# 37                       10521                                       94316
# 39                    42526908                                   129714758
# 43                   127908163                                   387224216
# 54                       94489                                     1669744
# 58                  2869681977                                  8774586577
# 61                   595806258                                   187075086
# 63                     1385625                                     3888383
# ..                         ...                                         ...
# 23                      341696                                      845981
# 25                     1535165                                     5185778
# 28                           0                                           0
# 29                       71329                                      567893
# 30                    38506020                                   127246165
# 33                        9547                                       71162
# 34                     2430801                                      829317
# 36                      717036                                     2277576
# 38                   215203629                                   655426306
# 39                      374667                                     3011036
# 40                     1050837                                    12269493
# 41                       86765                                      691399
# 43                       73459                                      387876
# 44                  5873200213                                 16179310610
# 45                    26638549                                    32596930
# 0                        57226                                      204671
# 1                       472023                                     1546178
# 2                      1532842                                     5611735
# 3                        13743                                      155220
# 4                        57339                                      191863
# 5                      2516800                                     1039358
# 6                   5901762392                                 16216842936
# 7                       717775                                     1954193
# 9                      3126291                                    10566761
# 10                     9967043                                    21872365
# 11                     6482442                                    40565964
# 12                    42419323                                    31128394
# 13                 12673773945                                 17168654996
# 14                   588759945                                   605925448
# 0                  20235599399                                 37522366174
#
#     libpfm.counter.INT_MISC:RECOVERY_CYCLES       ...        \
# 71                                  2303370       ...
# 15                                  2245504       ...
# 30                                  1571402       ...
# 47                                  1878281       ...
# 85                                  7027065       ...
# 90                                   727301       ...
# 23                                 14177950       ...
# 25                                        0       ...
# 36                                  2246462       ...
# 54                                        0       ...
# 59                                 10667673       ...
# 69                                        0       ...
# 78                                   809295       ...
# 2                                     43267       ...
# 14                                  9951356       ...
# 47                                        0       ...
# 63                                   580288       ...
# 74                                    99728       ...
# 81                                 34079316       ...
# 83                                  4390140       ...
# 1                                      1768       ...
# 7                                       409       ...
# 29                                 22576681       ...
# 37                                     2146       ...
# 39                                   518316       ...
# 43                                  1610595       ...
# 54                                    59446       ...
# 58                                 40108005       ...
# 61                                   351013       ...
# 63                                   301257       ...
# ..                                      ...       ...
# 23                                     3798       ...
# 25                                    17201       ...
# 28                                        0       ...
# 29                                     7113       ...
# 30                                   707714       ...
# 33                                     1288       ...
# 34                                    11756       ...
# 36                                     6957       ...
# 38                                  5992769       ...
# 39                                    24946       ...
# 40                                   215296       ...
# 41                                    12751       ...
# 43                                     7196       ...
# 44                                 67502122       ...
# 45                                  1934921       ...
# 0                                      1251       ...
# 1                                     24773       ...
# 2                                     28832       ...
# 3                                         0       ...
# 4                                      1146       ...
# 5                                     12887       ...
# 6                                  69629825       ...
# 7                                     50889       ...
# 9                                     35767       ...
# 10                                    65758       ...
# 11                                   932680       ...
# 12                                   212753       ...
# 13                                449333757       ...
# 14                                 10821418       ...
# 0                                 536683943       ...
#
#     libpfm.counter.UOPS_EXECUTED:CORE_CYCLES_GE_1  \
# 71                                      734647360
# 15                                      677360760
# 30                                      511755969
# 47                                      675830327
# 85                                     2205521989
# 90                                      225776091
# 23                                     4473417558
# 25                                        4218340
# 36                                      677220099
# 54                                         446762
# 59                                     3382573925
# 69                                        4129088
# 78                                      226259993
# 2                                        17733255
# 14                                     3995798417
# 47                                       20811062
# 63                                      168511678
# 74                                     1339040775
# 81                                    10626839304
# 83                                      180925865
# 1                                          668817
# 7                                           74340
# 29                                     8000172529
# 37                                          74500
# 39                                      169088458
# 43                                      505389801
# 54                                       31800398
# 58                                    11231339108
# 61                                     1343154584
# 63                                       91184248
# ..                                            ...
# 23                                        1233041
# 25                                              0
# 28                                              0
# 29                                              0
# 30                                      161747160
# 33                                         230618
# 34                                        1244620
# 36                                              0
# 38                                     1172592280
# 39                                        7943563
# 40                                       25389576
# 41                                              0
# 43                                         523799
# 44                                    21975316938
# 45                                       17442636
# 0                                               0
# 1                                         1057231
# 2                                               0
# 3                                          255351
# 4                                               0
# 5                                         1324719
# 6                                     22043520306
# 7                                          557537
# 9                                               0
# 10                                       14741311
# 11                                      197852980
# 12                                      134384326
# 13                                    47877827727
# 14                                     1247321165
# 0                                     73353158197
#
#     libpfm.counter.UOPS_EXECUTED:CORE_CYCLES_GE_2  \
# 71                                      596993361
# 15                                      549201649
# 30                                      414886105
# 47                                      549086393
# 85                                     1791282089
# 90                                      183388859
# 23                                     3630281365
# 25                                        3172698
# 36                                      550049104
# 54                                         264902
# 59                                     2745301023
# 69                                        3167793
# 78                                      183630323
# 2                                        12706292
# 14                                     3245740019
# 47                                       15873265
# 63                                      136703009
# 74                                     1082073175
# 81                                     8624268866
# 83                                      144594086
# 1                                          573856
# 7                                           30151
# 29                                     6491415083
# 37                                          30185
# 39                                      136780495
# 43                                      409873051
# 54                                       23688401
# 58                                     9110880230
# 61                                     1084813338
# 63                                       92557842
# ..                                            ...
# 23                                         892268
# 25                                              0
# 28                                              0
# 29                                          43098
# 30                                      127954954
# 33                                         154521
# 34                                        1352388
# 36                                              0
# 38                                      804108417
# 39                                        6933617
# 40                                       21618462
# 41                                          50891
# 43                                         211701
# 44                                    17822947437
# 45                                        8082889
# 0                                           30899
# 1                                          521040
# 2                                               0
# 3                                          254100
# 4                                           30818
# 5                                         1445588
# 6                                     17869127141
# 7                                          282020
# 9                                               0
# 10                                       21296853
# 11                                      185421159
# 12                                      108162251
# 13                                    39223891774
# 14                                      989156718
# 0                                     59654353764
#
#     libpfm.counter.UOPS_EXECUTED:THREAD  libpfm.counter.UOPS_ISSUED:ANY  \
# 71                           2215438952                      2034027702
# 15                           2043227374                      1872522334
# 30                           1538295417                      1411927731
# 47                           2035192437                      1869599378
# 85                           6646474530                      6098479033
# 90                            682603152                       622727758
# 23                          13469413434                     12354588065
# 25                              9312773                        10065696
# 36                           2045776785                      1867349343
# 54                              1171682                         1208268
# 59                          10194827203                      9350146831
# 69                              9156872                         9884326
# 78                            683234146                       623656842
# 2                              49627230                        40964978
# 14                          12040313055                     11039316708
# 47                             45928806                        49735382
# 63                            506489826                       464883836
# 74                           4414428892                      4215865856
# 81                          32014617395                     29342066731
# 83                            532823108                       507568485
# 1                               2134845                         1955584
# 7                                112685                          205672
# 29                          24085646187                     22093946791
# 37                               112628                          205741
# 39                            508307061                       465395216
# 43                           1518383542                      1392890335
# 54                             94468461                        75708935
# 58                          33796666726                     31004597624
# 61                           4424249251                      4223048660
# 63                            233772066                       187803063
# ..                                  ...                             ...
# 23                              3521729                         3407091
# 25                                    0                          455191
# 28                                    0                               0
# 29                                    0                          289450
# 30                            475373125                       433738713
# 33                               685110                          523581
# 34                             12641637                         3968569
# 36                                    0                         1131509
# 38                           2884508638                      2413197373
# 39                             24864382                        23014271
# 40                             96774491                        89350830
# 41                                    0                          342273
# 43                               791830                         1442945
# 44                          66490364075                     61189705629
# 45                             53454229                        17339083
# 0                                     0                          209655
# 1                               4762544                          911784
# 2                                     0                         2422728
# 3                                620345                          868259
# 4                                     0                          209500
# 5                              14325984                         4179578
# 6                           66701812827                     61326241945
# 7                               2844416                          983514
# 9                                     0                          968497
# 10                             20426869                       103829341
# 11                            541991740                       479694690
# 12                            435878189                       412079499
# 13                         126912271096                    120146053534
# 14                           3890554956                      3705451954
# 0                          202463054918                    190199065308
#
#     libpfm.counter.UOPS_RETIRED:RETIRE_SLOTS  time.inclusive.duration  \
# 71                                2018931157                     79.0
# 15                                1854839143                     99.0
# 30                                1398119385                    147.0
# 47                                1856585100                     48.0
# 85                                6055186996                    171.0
# 90                                 617021950                    148.0
# 23                               12264770097                    329.0
# 25                                  10149653                     47.0
# 36                                1852518878                    202.0
# 54                                    887835                     45.0
# 59                                9275795394                    213.0
# 69                                  10139498                     43.0
# 78                                 618831351                     95.0
# 2                                   35328209                     77.0
# 14                               10988434012                    469.0
# 47                                  50665471                    123.0
# 63                                 459585105                    124.0
# 74                                4177764133                 345831.0
# 81                               29117486931                   1082.0
# 83                                 473051338                     51.0
# 1                                    1935182                     35.0
# 7                                     203741                     38.0
# 29                               21974077968                1053554.0
# 37                                    204103                     62.0
# 39                                 460571875                    158.0
# 43                                1378591807                    178.0
# 54                                  67029353                    127.0
# 58                               30731516454                1576489.0
# 61                                4182201737                 346187.0
# 63                                 213029028                   1090.0
# ..                                       ...                      ...
# 23                                   3811495                     61.0
# 25                                   4195475                     49.0
# 28                                         0                     61.0
# 29                                    549935                     30.0
# 30                                 424740586                     78.0
# 33                                    309490                     19.0
# 34                                   5635626                    563.0
# 36                                   2244803                     51.0
# 38                                2404410377                    379.0
# 39                                  22978511                   3986.0
# 40                                  87894523                    348.0
# 41                                    633365                     37.0
# 43                                   1429924                    320.0
# 44                               60693175334                2816012.0
# 45                                  13380644                  10000.0
# 0                                     309869                    341.0
# 1                                     863465                    618.0
# 2                                    4768710                    503.0
# 3                                     776934                     54.0
# 4                                     340004                     43.0
# 5                                    5947636                    598.0
# 6                                60811493334                2829809.0
# 7                                    1784903                    623.0
# 9                                    8485946                   1045.0
# 10                                 127493017                    202.0
# 11                                 463594518                   2597.0
# 12                                 395218435                  17550.0
# 13                              116173133359                3572462.0
# 14                                3644743548                 128275.0
# 0                               185586961484               37213720.0
#
#     cali.caliper.version  \
# 71                 93888
# 15                     1
# 30                     1
# 47                     1
# 85                     2
# 90                     1
# 23                     3
# 25                     1
# 36                     2
# 54                     1
# 59                     3
# 69                     1
# 78                     1
# 2                      1
# 14                     1
# 47                     3
# 63                     1
# 74                     2
# 81                     5
# 83                     1
# 1                      1
# 7                      1
# 29                     2
# 37                     1
# 39                     1
# 43                     2
# 54                     2
# 58                     4
# 61                     2
# 63                     1
# ..                   ...
# 23                     1
# 25                     1
# 28                     1
# 29                     1
# 30                     1
# 33                     1
# 34                     1
# 36                     1
# 38                     1
# 39                     4
# 40                     2
# 41                     1
# 43                     2
# 44                     9
# 45                     1
# 0                      2
# 1                      1
# 2                      2
# 3                      1
# 4                      1
# 5                      5
# 6                      8
# 7                      2
# 9                      2
# 10                     3
# 11                     2
# 12                     9
# 13                     3
# 14                     5
# 0                     15
#
#                                                                                                                            function  \
# 71  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, addTupleToQueue, tupleToIndex)
# 15                       (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2, whichCellTuple)
# 30                   (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, indexToTuple)
# 47                         (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2, indexToTuple)
# 85                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, addTupleToQueue)
# 90                  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addTupleToQueue, tupleToIndex)
# 23                                 (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue)
# 25                                     (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell, whichCellTuple)
# 36                                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addTupleToQueue)
# 54                                       (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap, exchange, cellInfoMpiType)
# 59                                       (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2)
# 69                                       (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell, tupleToIndex)
# 78                                 (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, whichCellTuple)
# 2                                                     (main, initMC, initNuclearData, addIsotope, addReaction, NuclearDataReaction)
# 14                                                                  (main, initMC, initMesh, MC_Mesh_Domain, buildCells, makeFacet)
# 47                                                     (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell)
# 63                                                                      (main, initMC, initMesh, MC_Domain, findMaterial, isInside)
# 74                                                        (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap, exchange)
# 81                                                 (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter)
# 83                                                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, addNbrsToFlood)
# 1                                                                            (main, parseInputFile, readBlock, split, validKeyword)
# 7                                                                           (main, parseInputFile, blockStart, split, validKeyword)
# 29                                                                             (main, initMC, initMesh, MC_Mesh_Domain, buildCells)
# 37                                                                                  (main, parseInputFile, blockStart, split, chop)
# 39                                                                              (main, initMC, initMesh, MC_Domain, findCellCenter)
# 43                                                                                (main, initMC, initMesh, MC_Domain, findMaterial)
# 54                                                                         (main, initMC, initNuclearData, addIsotope, addReaction)
# 58                                                                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain)
# 61                                                                  (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap)
# 63                                                                (main, cycleFinalize, CycleFinalize, PrintSummary, ScalarFluxSum)
# ..                                                                                                                              ...
# 23                                                                                               (main, cycleInit, CycleInitialize)
# 25                                                                                                   (main, freeArgs, myOptionFree)
# 28                                                                                              (main, printParameters, operator<<)
# 29                                                                                        (main, parseInputFile, scanGeometryBlock)
# 30                                                                                                  (main, cycleTracking, SumTasks)
# 33                                                                                                      (main, initMC, initGPUInfo)
# 34                                                                                   (main, coralBenchmarkCorrectness, FluenceTest)
# 36                                                                                                  (main, processArgs, findOption)
# 38                                                                                                  (main, cycleTracking, collapse)
# 39                                                                                                (main, parseInputFile, readBlock)
# 40                                                                                        (main, cycleInit, clearCrossSectionCache)
# 41                                                                                        (main, parseInputFile, scanMaterialBlock)
# 43                                                                                               (main, parseInputFile, blockStart)
# 44                                                                                                         (main, initMC, initMesh)
# 45                                                                                                       (main, initMC, MonteCarlo)
# 0                                                                                                           (main, printParameters)
# 1                                                                                                               (main, ~MonteCarlo)
# 2                                                                                                               (main, processArgs)
# 3                                                                                                               (main, printBanner)
# 4                                                                                                            (main, supplyDefaults)
# 5                                                                                                 (main, coralBenchmarkCorrectness)
# 6                                                                                                                    (main, initMC)
# 7                                                                                                                  (main, gameOver)
# 9                                                                                                                  (main, freeArgs)
# 10                                                                                                                   (main, addArg)
# 11                                                                                                            (main, cycleFinalize)
# 12                                                                                                           (main, parseInputFile)
# 13                                                                                                            (main, cycleTracking)
# 14                                                                                                                (main, cycleInit)
# 0                                                                                                                           (main,)
#
#     parent_hash#function  depth#function
# 71   5331452723580995626               9
# 15   1290044161575942532               8
# 30  -4933507252616422133               8
# 47   1290044161575942532               8
# 85  -4933507252616422133               8
# 90  -2901336579335736432               8
# 23   6957787860313903023               7
# 25   -572252942354143546               7
# 36   6957787860313903023               7
# 54   4964793335720556777               7
# 59   6957787860313903023               7
# 69   -572252942354143546               7
# 78   6957787860313903023               7
# 2    1578644897819887607               6
# 14  -3346546285056646112               6
# 47   1824199118260379446               6
# 63   -705510571855917191               6
# 74   3226576455897967531               6
# 81   1824199118260379446               6
# 83   1824199118260379446               6
# 1   -2215984096607780950               5
# 7   -3683541750864208282               5
# 29   1551109911967735083               5
# 37  -3683541750864208282               5
# 39   1635650414372769522               5
# 43   1635650414372769522               5
# 54  -2868132710735568508               5
# 58   4316958779520896706               5
# 61   4316958779520896706               5
# 63  -2939088902177280270               5
# ..                   ...             ...
# 23   9031087567878469606               3
# 25   3566080296536805615               3
# 28  -8404990865778211590               3
# 29   5362067455521828759               3
# 30   8375893045446190810               3
# 33   -611320776416371186               3
# 34  -2281267291879510595               3
# 36  -5143781023991094254               3
# 38   8375893045446190810               3
# 39   5362067455521828759               3
# 40   9031087567878469606               3
# 41   5362067455521828759               3
# 43   5362067455521828759               3
# 44   -611320776416371186               3
# 45   -611320776416371186               3
# 0    1128851083484916900               2
# 1    1128851083484916900               2
# 2    1128851083484916900               2
# 3    1128851083484916900               2
# 4    1128851083484916900               2
# 5    1128851083484916900               2
# 6    1128851083484916900               2
# 7    1128851083484916900               2
# 9    1128851083484916900               2
# 10   1128851083484916900               2
# 11   1128851083484916900               2
# 12   1128851083484916900               2
# 13   1128851083484916900               2
# 14   1128851083484916900               2
# 0                3527539               1
#
# [105 rows x 25 columns]

# %% [markdown]
# # Derive Topdown Analysis metrics
# Calculates the topdown derived metrics as described in http://ieeexplore.ieee.org/document/6844459/

# %%
import topdown

# %%
df_td = topdown.derive_topdown_ivb(mrt.df_nodes)
df_td
# Out:
#           hash#function  time.inclusive.duration  cali.caliper.version  \
# 71  2574226508381785094                     79.0                 93888
# 15 -7252534472619379718                     99.0                     1
# 30 -3677243502532151653                    147.0                     1
# 47  -927934058046326774                     48.0                     1
# 85  5331452723580995626                    171.0                     2
# 90  5955584031965748850                    148.0                     1
# 23 -4933507252616422133                    329.0                     3
# 25 -4134057073213068368                     47.0                     1
# 36 -2901336579335736432                    202.0                     2
# 54  -376670115672843596                     45.0                     1
# 59  1290044161575942532                    213.0                     3
# 69  3137460780166019260                     43.0                     1
# 78  4443938504809891159                     95.0                     1
# 2  -8885906963766464142                     77.0                     1
# 14 -7264013457032837659                    469.0                     1
# 47  -572252942354143546                    123.0                     3
# 63  2905914891805626554                    124.0                     1
# 74  4964793335720556777                 345831.0                     2
# 81  6957787860313903023                   1082.0                     5
# 83  7959062406079742903                     51.0                     1
# 1  -8973096192519033624                     35.0                     1
# 7  -8376760555805231436                     38.0                     1
# 29 -3346546285056646112                1053554.0                     2
# 37 -1834282723900083241                     62.0                     1
# 39 -1329505548080475541                    158.0                     1
# 43  -705510571855917191                    178.0                     2
# 54  1578644897819887607                    127.0                     2
# 58  1824199118260379446                1576489.0                     4
# 61  3226576455897967531                 346187.0                     2
# 63  3768386929182066311                   1090.0                     1
# ..                  ...                      ...                   ...
# 23  -788602314893872686                     61.0                     1
# 25  -515489496254773016                     49.0                     1
# 28  1327647275769230351                     61.0                     1
# 29  1684812234173510571                     30.0                     1
# 30  3152381168709113512                     78.0                     1
# 33  3974207558341453912                     19.0                     1
# 34  4399659537923052962                    563.0                     1
# 36  4948303505321721652                     51.0                     1
# 38  5561175753082870147                    379.0                     1
# 39  5810354523748618040                   3986.0                     4
# 40  6392707864436864065                    348.0                     2
# 41  8012283347977419031                     37.0                     1
# 43  8605958245948087580                    320.0                     2
# 44  8826531664285963129                2816012.0                     9
# 45  8886119691787648251                  10000.0                     1
# 0  -8404990865778211590                    341.0                     2
# 1  -7516306253691115888                    618.0                     1
# 2  -5143781023991094254                    503.0                     2
# 3  -3675806031077117392                     54.0                     1
# 4  -3660262160707739778                     43.0                     1
# 5  -2281267291879510595                    598.0                     5
# 6   -611320776416371186                2829809.0                     8
# 7    646242863799796493                    623.0                     2
# 9   3566080296536805615                   1045.0                     2
# 10  3947555474804788133                    202.0                     3
# 11  4465666093020475086                   2597.0                     2
# 12  5362067455521828759                  17550.0                     9
# 13  8375893045446190810                3572462.0                     3
# 14  9031087567878469606                 128275.0                     5
# 0   1128851083484916900               37213720.0                    15
#
#                                                                                                                            function  \
# 71  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, addTupleToQueue, tupleToIndex)
# 15                       (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2, whichCellTuple)
# 30                   (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, indexToTuple)
# 47                         (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2, indexToTuple)
# 85                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, addTupleToQueue)
# 90                  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addTupleToQueue, tupleToIndex)
# 23                                 (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue)
# 25                                     (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell, whichCellTuple)
# 36                                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addTupleToQueue)
# 54                                       (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap, exchange, cellInfoMpiType)
# 59                                       (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2)
# 69                                       (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell, tupleToIndex)
# 78                                 (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, whichCellTuple)
# 2                                                     (main, initMC, initNuclearData, addIsotope, addReaction, NuclearDataReaction)
# 14                                                                  (main, initMC, initMesh, MC_Mesh_Domain, buildCells, makeFacet)
# 47                                                     (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell)
# 63                                                                      (main, initMC, initMesh, MC_Domain, findMaterial, isInside)
# 74                                                        (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap, exchange)
# 81                                                 (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter)
# 83                                                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, addNbrsToFlood)
# 1                                                                            (main, parseInputFile, readBlock, split, validKeyword)
# 7                                                                           (main, parseInputFile, blockStart, split, validKeyword)
# 29                                                                             (main, initMC, initMesh, MC_Mesh_Domain, buildCells)
# 37                                                                                  (main, parseInputFile, blockStart, split, chop)
# 39                                                                              (main, initMC, initMesh, MC_Domain, findCellCenter)
# 43                                                                                (main, initMC, initMesh, MC_Domain, findMaterial)
# 54                                                                         (main, initMC, initNuclearData, addIsotope, addReaction)
# 58                                                                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain)
# 61                                                                  (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap)
# 63                                                                (main, cycleFinalize, CycleFinalize, PrintSummary, ScalarFluxSum)
# ..                                                                                                                              ...
# 23                                                                                               (main, cycleInit, CycleInitialize)
# 25                                                                                                   (main, freeArgs, myOptionFree)
# 28                                                                                              (main, printParameters, operator<<)
# 29                                                                                        (main, parseInputFile, scanGeometryBlock)
# 30                                                                                                  (main, cycleTracking, SumTasks)
# 33                                                                                                      (main, initMC, initGPUInfo)
# 34                                                                                   (main, coralBenchmarkCorrectness, FluenceTest)
# 36                                                                                                  (main, processArgs, findOption)
# 38                                                                                                  (main, cycleTracking, collapse)
# 39                                                                                                (main, parseInputFile, readBlock)
# 40                                                                                        (main, cycleInit, clearCrossSectionCache)
# 41                                                                                        (main, parseInputFile, scanMaterialBlock)
# 43                                                                                               (main, parseInputFile, blockStart)
# 44                                                                                                         (main, initMC, initMesh)
# 45                                                                                                       (main, initMC, MonteCarlo)
# 0                                                                                                           (main, printParameters)
# 1                                                                                                               (main, ~MonteCarlo)
# 2                                                                                                               (main, processArgs)
# 3                                                                                                               (main, printBanner)
# 4                                                                                                            (main, supplyDefaults)
# 5                                                                                                 (main, coralBenchmarkCorrectness)
# 6                                                                                                                    (main, initMC)
# 7                                                                                                                  (main, gameOver)
# 9                                                                                                                  (main, freeArgs)
# 10                                                                                                                   (main, addArg)
# 11                                                                                                            (main, cycleFinalize)
# 12                                                                                                           (main, parseInputFile)
# 13                                                                                                            (main, cycleTracking)
# 14                                                                                                                (main, cycleInit)
# 0                                                                                                                           (main,)
#
#     parent_hash#function  depth#function  retiring  bad_speculation  \
# 71   5331452723580995626               9  0.537467         0.006472
# 15   1290044161575942532               8  0.533805         0.007674
# 30  -4933507252616422133               8  0.536522         0.007711
# 47   1290044161575942532               8  0.536153         0.005928
# 85  -4933507252616422133               8  0.536578         0.006327
# 90  -2901336579335736432               8  0.531663         0.007423
# 23   6957787860313903023               7  0.536236         0.006407
# 25   -572252942354143546               7  0.626243        -0.005180
# 36   6957787860313903023               7  0.531681         0.006835
# 54   4964793335720556777               7  0.303525         0.109547
# 59   6957787860313903023               7  0.534352         0.006741
# 69   -572252942354143546               7  0.631344        -0.015889
# 78   6957787860313903023               7  0.531054         0.006919
# 2    1578644897819887607               6  0.916804         0.150771
# 14  -3346546285056646112               6  0.533569         0.004404
# 47   1824199118260379446               6  0.631054        -0.011585
# 63   -705510571855917191               6  0.540253         0.008957
# 74   3226576455897967531               6  0.564941         0.005206
# 81   1824199118260379446               6  0.534435         0.006624
# 83   1824199118260379446               6  0.476890         0.052500
# 1   -2215984096607780950               5  0.641556         0.009108
# 7   -3683541750864208282               5  0.540020         0.009454
# 29   1551109911967735083               5  0.532665         0.005095
# 37  -3683541750864208282               5  0.536396         0.026864
# 39   1635650414372769522               5  0.534755         0.008007
# 43   1635650414372769522               5  0.539861         0.008122
# 54  -2868132710735568508               5  0.941528         0.125258
# 58   4316958779520896706               5  0.533049         0.007519
# 61   4316958779520896706               5  0.564690         0.005705
# 63  -2939088902177280270               5  0.481190        -0.054258
# ..                   ...             ...       ...              ...
# 23   9031087567878469606               3  0.563171        -0.057508
# 25   3566080296536805615               3  0.210650        -0.184341
# 28  -8404990865778211590               3       NaN              NaN
# 29   5362067455521828759               3  0.235613        -0.099412
# 30   8375893045446190810               3  0.477801         0.013307
# 33   -611320776416371186               3  1.312377         0.929689
# 34  -2281267291879510595               3  0.391540        -0.112553
# 36  -5143781023991094254               3  0.220571        -0.106656
# 38   8375893045446190810               3  0.346102         0.004715
# 39   5362067455521828759               3  0.627323         0.003700
# 40   9031087567878469606               3  0.711617         0.018763
# 41   5362067455521828759               3  0.237653        -0.090086
# 43   5362067455521828759               3  0.531007         0.015524
# 44   -611320776416371186               3  0.534209         0.006747
# 45   -611320776416371186               3  0.079220         0.069258
# 0    1128851083484916900               2  0.261646        -0.080393
# 1    1128851083484916900               2  0.129190         0.022055
# 2    1128851083484916900               2  0.211555        -0.098959
# 3    1128851083484916900               2  0.200856         0.023610
# 4    1128851083484916900               2  0.290856        -0.107718
# 5    1128851083484916900               2  0.388695        -0.112179
# 6    1128851083484916900               2  0.533707         0.006962
# 7    1128851083484916900               2  0.288573        -0.096654
# 9    1128851083484916900               2  0.209184        -0.181784
# 10   1128851083484916900               2  0.452240        -0.083006
# 11   1128851083484916900               2  0.430603         0.018420
# 12   1128851083484916900               2  0.610630         0.027366
# 13   1128851083484916900               2  0.468424         0.023266
# 14   1128851083484916900               2  0.534524         0.015251
# 0                3527539               1  0.488457         0.017789
#
#     frontend_bound  backend_bound      ...       machine_clear  \
# 71        0.151175       0.304887      ...            0.145168
# 15        0.151219       0.307302      ...            0.134794
# 30        0.150515       0.305252      ...            0.144138
# 47        0.149674       0.308245      ...            0.158463
# 85        0.151955       0.305139      ...            0.141289
# 90        0.151012       0.309902      ...            0.135983
# 23        0.151778       0.305580      ...            0.142507
# 25        0.005296       0.373641      ...            0.003607
# 36        0.152466       0.309017      ...            0.133991
# 54        0.000000       0.586928      ...            0.000000
# 59        0.151356       0.307550      ...            0.145405
# 69        0.005259       0.379286      ...            0.004279
# 78        0.152753       0.309273      ...            0.123935
# 2         0.017239      -0.084814      ...            0.019849
# 14        0.148130       0.313898      ...            0.181358
# 47        0.005650       0.374881      ...            0.004347
# 63        0.151116       0.299674      ...            0.127187
# 74        0.024848       0.405005      ...            0.018868
# 81        0.151915       0.307025      ...            0.143245
# 83        0.167546       0.303064      ...            0.017377
# 1         0.078375       0.270961      ...            0.139175
# 7         0.091748       0.358777      ...            0.155556
# 29        0.149487       0.312753      ...            0.164823
# 37        0.247869       0.188871      ...            0.075000
# 39        0.150607       0.306630      ...            0.136713
# 43        0.151638       0.300379      ...            0.138000
# 54        0.023454      -0.090239      ...            0.034784
# 58        0.152198       0.307233      ...            0.128015
# 61        0.025259       0.404346      ...            0.012993
# 63        0.008783       0.564286      ...            0.011499
# ..             ...            ...      ...                 ...
# 23        0.124999       0.369338      ...            0.086957
# 25        0.260372       0.713318      ...            0.331341
# 28             NaN            NaN      ...                 NaN
# 29        0.243307       0.620491      ...            0.007299
# 30        0.143142       0.365750      ...            0.108016
# 33        0.301759      -1.543825      ...            0.212121
# 34        0.057617       0.663396      ...            0.017197
# 36        0.223791       0.662295      ...            0.205939
# 38        0.094345       0.554837      ...            0.095340
# 39        0.082203       0.286774      ...            0.132525
# 40        0.099337       0.170283      ...            0.051278
# 41        0.259428       0.593006      ...            0.003337
# 43        0.144039       0.309429      ...            0.080420
# 44        0.142407       0.316637      ...            0.136286
# 45        0.192989       0.658534      ...            0.863529
# 0         0.172819       0.645928      ...            0.021583
# 1         0.231336       0.617418      ...            0.089744
# 2         0.248954       0.638450      ...            0.132825
# 3         0.040128       0.735406      ...            0.000000
# 4         0.164129       0.652733      ...            0.031250
# 5         0.067925       0.655559      ...            0.027570
# 6         0.142326       0.317006      ...            0.139779
# 7         0.315943       0.492139      ...            0.339405
# 9         0.260478       0.712121      ...            0.330426
# 10        0.077585       0.553181      ...            0.023342
# 11        0.037679       0.513298      ...            0.093291
# 12        0.048095       0.313909      ...            0.042692
# 13        0.069226       0.439084      ...            0.010462
# 14        0.088863       0.361362      ...            0.043036
# 0         0.098757       0.394996      ...            0.028332
#
#     frontend_latency  frontend_bandwidth  memory_bound  core_bound  mem_bound  \
# 71          0.604700            0.395300      0.111491    0.250971   0.000098
# 15          0.604877            0.395123      0.112407    0.251637   0.000056
# 30          0.602061            0.397939      0.111459    0.252964   0.000072
# 47          0.598696            0.401304      0.112065    0.250568   0.000077
# 85          0.607822            0.392178      0.112044    0.251388   0.000095
# 90          0.604047            0.395953      0.111637    0.250623   0.000076
# 23          0.607114            0.392886      0.112162    0.252035   0.000093
# 25          0.021183            0.978817      0.024334    0.447282   0.000441
# 36          0.609864            0.390136      0.112526    0.250553   0.000085
# 54          0.000005            0.999995      0.000000    0.430898   0.030078
# 59          0.605425            0.394575      0.112364    0.251303   0.000074
# 69          0.021034            0.978966      0.022996    0.423184   0.000000
# 78          0.611014            0.388986      0.112481    0.250888   0.000040
# 2           0.068955            0.931045      0.007298    0.626523   0.001403
# 14          0.592519            0.407481      0.114173    0.249923   0.000727
# 47          0.022598            0.977402      0.024614    0.431874   0.000267
# 63          0.604463            0.395537      0.111133    0.254561   0.000092
# 74          0.099392            0.900608      0.170392    0.262432   0.000107
# 81          0.607662            0.392338      0.112503    0.251711   0.000085
# 83          0.670183            0.329817      0.153730    0.259777   0.000296
# 1           0.313499            0.686501      0.000000    0.271388   0.000000
# 7           0.366991            0.633009      0.000000    0.573722   0.000000
# 29          0.597949            0.402051      0.115897    0.250134   0.000794
# 37          0.991475            0.008525      0.000000    0.574390   0.000000
# 39          0.602430            0.397570      0.115223    0.254091   0.000127
# 43          0.606553            0.393447      0.111752    0.254172   0.000089
# 54          0.093816            0.906184      0.006743    0.572676   0.001314
# 58          0.608794            0.391206      0.113434    0.252177   0.000095
# 61          0.101037            0.898963      0.170806    0.262440   0.000109
# 63          0.035132            0.964868      0.018304    0.000093   0.000106
# ..               ...                 ...           ...         ...        ...
# 23          0.499995            0.500005      0.224942    0.262875   0.000000
# 25          1.041490           -0.041490      0.168287    0.127869   0.000000
# 28               inf                -inf           inf         NaN        NaN
# 29          0.973229            0.026771      0.173379    0.082027   0.000000
# 30          0.572569            0.427431      0.179707    0.257668   0.000115
# 33          1.207036           -0.207036      0.000000    1.519744   0.000000
# 34          0.230470            0.769530      0.347404    0.018847   0.000701
# 36          0.895163            0.104837      0.129717    0.201764   0.000000
# 38          0.377381            0.622619      0.233320    0.298074   0.000939
# 39          0.328810            0.671190      0.000000    0.271354   0.000006
# 40          0.397348            0.602652      0.084782    0.149664   0.000030
# 41          1.037713           -0.037713      0.170282    0.078228   0.000000
# 43          0.576156            0.423844      0.021672    0.557644   0.000000
# 44          0.569628            0.430372      0.118115    0.252809   0.000400
# 45          0.771955            0.228045      0.718801    0.422015   0.074666
# 0           0.691276            0.308724      0.770185    0.474356   0.000000
# 1           0.925346            0.074654      1.289460   -0.102709   0.404276
# 2           0.995816            0.004184      0.142262    0.213982   0.001072
# 3           0.160512            0.839488      0.035859    0.413104        NaN
# 4           0.656516            0.343484      0.155319   -0.006440   0.000000
# 5           0.271700            0.728300      0.351969    0.012028   0.005460
# 6           0.569303            0.430697      0.118970    0.253632   0.000508
# 7           1.263771           -0.263771      0.622959    0.344967   0.268077
# 9           1.041912           -0.041912      0.168471    0.128791   0.000000
# 10          0.310340            0.689660      0.105794    0.028711   0.000000
# 11          0.150717            0.849283      0.073193    0.072048   0.000185
# 12          0.192379            0.807621      0.149088    0.285821   0.000852
# 13          0.276904            0.723096      0.185443    0.247159   0.000154
# 14          0.355451            0.644549      0.168545    0.251857   0.000223
# 0           0.395029            0.604971      0.163454    0.250706   0.000440
#
#     l1_bound  l2_bound  l3_bound  uncore_bound
# 71  0.105106  0.004113  0.002175      0.002272
# 15  0.105567  0.004236  0.002548      0.002604
# 30  0.105273  0.004103  0.002010      0.002082
# 47  0.105379  0.004169  0.002439      0.002516
# 85  0.105458  0.004230  0.002261      0.002356
# 90  0.104760  0.004543  0.002258      0.002334
# 23  0.105559  0.004214  0.002297      0.002390
# 25  0.016665  0.006505  0.000724      0.001165
# 36  0.105445  0.004398  0.002598      0.002682
# 54 -0.042341 -0.000692  0.012955      0.043033
# 59  0.105537  0.004298  0.002456      0.002530
# 69  0.017873  0.004670  0.000453      0.000453
# 78  0.105307  0.004418  0.002715      0.002755
# 2   0.001754  0.003183  0.000958      0.002361
# 14  0.106257  0.005560  0.001628      0.002355
# 47  0.018163  0.005339  0.000845      0.001112
# 63  0.104414  0.004462  0.002165      0.002257
# 74  0.170162 -0.000005  0.000128      0.000235
# 81  0.105585  0.004315  0.002519      0.002604
# 83  0.117296  0.010495  0.025643      0.025939
# 1  -0.001674  0.001408  0.000265      0.000265
# 7  -0.001940  0.001940  0.000000      0.000000
# 29  0.106917  0.005410  0.002776      0.003570
# 37 -0.004152  0.004152  0.000000      0.000000
# 39  0.105973  0.005041  0.004081      0.004209
# 43  0.104820  0.004550  0.002293      0.002382
# 54  0.000532  0.003488  0.001409      0.002722
# 58  0.105704  0.004479  0.003156      0.003251
# 61  0.170467 -0.000024  0.000255      0.000363
# 63  0.009552  0.001213  0.007432      0.007538
# ..       ...       ...       ...           ...
# 23  0.169888  0.011318  0.043736      0.043736
# 25  0.155076  0.006994  0.006216      0.006216
# 28       inf       inf       NaN           inf
# 29  0.113692  0.014911  0.044775      0.044775
# 30  0.117657  0.015224  0.046711      0.046826
# 33  0.000000  0.000000  0.000000      0.000000
# 34  0.334006  0.000611  0.012087      0.012788
# 36  0.114487  0.008141  0.007089      0.007089
# 38  0.130255  0.021011  0.081114      0.082053
# 39 -0.003930  0.003016  0.000909      0.000915
# 40  0.051198  0.002093  0.031462      0.031492
# 41  0.118372  0.011540  0.040369      0.040369
# 43  0.015787  0.005885  0.000000      0.000000
# 44  0.110172  0.004601  0.002942      0.003342
# 45  0.650150 -0.017045  0.011030      0.085696
# 0   0.477757  0.025426  0.267001      0.267001
# 1   0.686002  0.071766  0.127417      0.531692
# 2   0.108707  0.009489  0.022993      0.024065
# 3  -0.081667 -0.019505       NaN      0.137031
# 4   0.146966  0.005793  0.002560      0.002560
# 5   0.330192  0.001093  0.015224      0.020684
# 6   0.110911  0.004571  0.002979      0.003488
# 7   0.314746 -0.134761  0.174897      0.442974
# 9   0.156003  0.006754  0.005714      0.005714
# 10  0.096108  0.004712  0.004973      0.004973
# 11  0.054443  0.003145  0.015419      0.015604
# 12  0.141534 -0.000045  0.006747      0.007599
# 13  0.151520  0.003671  0.030098      0.030252
# 14  0.161756  0.001018  0.005548      0.005771
# 0   0.137907  0.003898  0.021210      0.021649
#
# [105 rows x 21 columns]

# %% [markdown]
# # Determine Topdown boundedness
# Using derived metrics, determines which function paths are bound by which resources

# %%
pd.set_option("display.max_rows",999)

dfb = topdown.analyze_topdown_metrics(df_td)
sorted_dfb = dfb.sort_values(['depth#function', 'time.inclusive.duration'], ascending=[True, False])
sorted_dfb[['function','time.inclusive.duration', 'boundedness', 'memory_bound', 'l1_bound', 'l2_bound', 'l3_bound']].dropna()
# Out:
#                                                                                                                            function  \
# 0                                                                                                                           (main,)
# 13                                                                                                            (main, cycleTracking)
# 6                                                                                                                    (main, initMC)
# 14                                                                                                                (main, cycleInit)
# 12                                                                                                           (main, parseInputFile)
# 11                                                                                                            (main, cycleFinalize)
# 9                                                                                                                  (main, freeArgs)
# 7                                                                                                                  (main, gameOver)
# 1                                                                                                               (main, ~MonteCarlo)
# 5                                                                                                 (main, coralBenchmarkCorrectness)
# 2                                                                                                               (main, processArgs)
# 0                                                                                                           (main, printParameters)
# 10                                                                                                                   (main, addArg)
# 4                                                                                                            (main, supplyDefaults)
# 44                                                                                                         (main, initMC, initMesh)
# 45                                                                                                       (main, initMC, MonteCarlo)
# 39                                                                                                (main, parseInputFile, readBlock)
# 9                                                                                                   (main, initMC, initNuclearData)
# 11                                                                                             (main, cycleInit, PopulationControl)
# 6                                                                                              (main, cycleFinalize, CycleFinalize)
# 2                                                                                     (main, cycleInit, RouletteLowWeightParticles)
# 16                                                                                                      (main, initMC, initTallies)
# 0                                                                                               (main, gameOver, Cumulative_Report)
# 34                                                                                   (main, coralBenchmarkCorrectness, FluenceTest)
# 38                                                                                                  (main, cycleTracking, collapse)
# 40                                                                                        (main, cycleInit, clearCrossSectionCache)
# 43                                                                                               (main, parseInputFile, blockStart)
# 10                                                                                                    (main, addArg, myOptionAlloc)
# 30                                                                                                  (main, cycleTracking, SumTasks)
# 7                                                                                                        (main, addArg, lastOption)
# 23                                                                                               (main, cycleInit, CycleInitialize)
# 36                                                                                                  (main, processArgs, findOption)
# 25                                                                                                   (main, freeArgs, myOptionFree)
# 41                                                                                        (main, parseInputFile, scanMaterialBlock)
# 4                                                                                     (main, parseInputFile, scanCrossSectionBlock)
# 20                                                                                               (main, parseInputFile, InputBlock)
# 29                                                                                        (main, parseInputFile, scanGeometryBlock)
# 1                                                                                               (main, parseInputFile, deserialize)
# 15                                                                                                     (main, initMC, initTimeInfo)
# 12                                                                                               (main, initMC, checkCrossSections)
# 33                                                                                                      (main, initMC, initGPUInfo)
# 56                                                                                     (main, initMC, initMesh, buildMeshPartition)
# 47                                                                                         (main, initMC, initMesh, MC_Mesh_Domain)
# 48                                                                                              (main, initMC, initMesh, MC_Domain)
# 34                                                                      (main, cycleInit, PopulationControl, PopulationControlGuts)
# 35                                                                                   (main, initMC, initTallies, InitializeTallies)
# 28                                                                               (main, cycleFinalize, CycleFinalize, PrintSummary)
# 39                                                                                    (main, cycleFinalize, CycleFinalize, compute)
# 29                                                                                      (main, initMC, initNuclearData, addIsotope)
# 0                                                                 (main, cycleInit, clearCrossSectionCache, clearCrossSectionCache)
# 22                                                                                        (main, parseInputFile, blockStart, split)
# 33                                                                                         (main, parseInputFile, readBlock, split)
# 65                                                                          (main, cycleInit, RouletteLowWeightParticles, collapse)
# 51                                                                                   (main, initMC, initMesh, getBoundaryCondition)
# 43                                                                                         (main, addArg, myOptionAlloc, dupString)
# 30                                                                                     (main, initMC, initNuclearData, NuclearData)
# 16                                                                                     (main, parseInputFile, readBlock, isComment)
# 41                                                                                       (main, parseInputFile, readBlock, addPair)
# 42                                                                                  (main, initMC, initMesh, initializeCentersGrid)
# 50                                                                    (main, gameOver, Cumulative_Report, Print_Cumulative_Heading)
# 26                                                                                   (main, cycleFinalize, CycleFinalize, SumTasks)
# 17                                                                                    (main, initMC, initMesh, DecompositionObject)
# 12                                                                                          (main, initMC, initMesh, MpiCommObject)
# 31                                                                                          (main, initMC, initMesh, MeshPartition)
# 58                                                                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain)
# 29                                                                             (main, initMC, initMesh, MC_Mesh_Domain, buildCells)
# 61                                                                  (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap)
# 82                                                                       (main, initMC, initMesh, MC_Mesh_Domain, bootstrapNodeMap)
# 63                                                                (main, cycleFinalize, CycleFinalize, PrintSummary, ScalarFluxSum)
# 43                                                                                (main, initMC, initMesh, MC_Domain, findMaterial)
# 39                                                                              (main, initMC, initMesh, MC_Domain, findCellCenter)
# 54                                                                         (main, initMC, initNuclearData, addIsotope, addReaction)
# 37                                                                                  (main, parseInputFile, blockStart, split, chop)
# 75                                                                                  (main, initMC, initMesh, MC_Domain, cellVolume)
# 71                                                                                   (main, parseInputFile, readBlock, split, chop)
# 7                                                                           (main, parseInputFile, blockStart, split, validKeyword)
# 76                                                                       (main, cycleFinalize, CycleFinalize, PrintSummary, Print0)
# 1                                                                            (main, parseInputFile, readBlock, split, validKeyword)
# 74                                                        (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap, exchange)
# 81                                                 (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter)
# 14                                                                  (main, initMC, initMesh, MC_Mesh_Domain, buildCells, makeFacet)
# 63                                                                      (main, initMC, initMesh, MC_Domain, findMaterial, isInside)
# 47                                                     (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell)
# 2                                                     (main, initMC, initNuclearData, addIsotope, addReaction, NuclearDataReaction)
# 83                                                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, addNbrsToFlood)
# 23                                 (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue)
# 59                                       (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2)
# 36                                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addTupleToQueue)
# 78                                 (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, whichCellTuple)
# 25                                     (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell, whichCellTuple)
# 54                                       (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap, exchange, cellInfoMpiType)
# 69                                       (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell, tupleToIndex)
# 85                (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, addTupleToQueue)
# 90                  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addTupleToQueue, tupleToIndex)
# 30                   (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, indexToTuple)
# 15                       (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2, whichCellTuple)
# 47                         (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2, indexToTuple)
# 71  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, addTupleToQueue, tupleToIndex)
#
#     time.inclusive.duration  \
# 0                37213720.0
# 13                3572462.0
# 6                 2829809.0
# 14                 128275.0
# 12                  17550.0
# 11                   2597.0
# 9                    1045.0
# 7                     623.0
# 1                     618.0
# 5                     598.0
# 2                     503.0
# 0                     341.0
# 10                    202.0
# 4                      43.0
# 44                2816012.0
# 45                  10000.0
# 39                   3986.0
# 9                    3690.0
# 11                   2945.0
# 6                    2553.0
# 2                    1574.0
# 16                   1377.0
# 0                     588.0
# 34                    563.0
# 38                    379.0
# 40                    348.0
# 43                    320.0
# 10                    134.0
# 30                     78.0
# 7                      63.0
# 23                     61.0
# 36                     51.0
# 25                     49.0
# 41                     37.0
# 4                      36.0
# 20                     33.0
# 29                     30.0
# 1                      28.0
# 15                     22.0
# 12                     19.0
# 33                     19.0
# 56                1578416.0
# 47                1058573.0
# 48                 179145.0
# 34                   2716.0
# 35                   1325.0
# 28                   1258.0
# 39                    983.0
# 29                    385.0
# 0                     310.0
# 22                    224.0
# 33                    168.0
# 65                     91.0
# 51                     67.0
# 43                     51.0
# 30                     46.0
# 16                     39.0
# 41                     35.0
# 42                     28.0
# 50                     27.0
# 26                     25.0
# 17                     23.0
# 12                     19.0
# 31                     19.0
# 58                1576489.0
# 29                1053554.0
# 61                 346187.0
# 82                   2096.0
# 63                   1090.0
# 43                    178.0
# 39                    158.0
# 54                    127.0
# 37                     62.0
# 75                     55.0
# 71                     49.0
# 7                      38.0
# 76                     38.0
# 1                      35.0
# 74                 345831.0
# 81                   1082.0
# 14                    469.0
# 63                    124.0
# 47                    123.0
# 2                      77.0
# 83                     51.0
# 23                    329.0
# 59                    213.0
# 36                    202.0
# 78                     95.0
# 25                     47.0
# 54                     45.0
# 69                     43.0
# 85                    171.0
# 90                    148.0
# 30                    147.0
# 15                     99.0
# 47                     48.0
# 71                     79.0
#
#                                                          boundedness  \
# 0                                                  [retiring 48.85%]
# 13                                                 [retiring 46.84%]
# 6                                                  [retiring 53.37%]
# 14                                                 [retiring 53.45%]
# 12                                                 [retiring 61.06%]
# 11        [backend_bound 51.33%, memory_bound 7.32%, l1_bound 5.44%]
# 9       [backend_bound 71.21%, memory_bound 16.85%, l1_bound 15.60%]
# 7   [backend_bound 49.21%, memory_bound 62.30%, uncore_bound 44.30%]
# 1      [backend_bound 61.74%, memory_bound 128.95%, l1_bound 68.60%]
# 5       [backend_bound 65.56%, memory_bound 35.20%, l1_bound 33.02%]
# 2                          [backend_bound 63.84%, core_bound 21.40%]
# 0       [backend_bound 64.59%, memory_bound 77.02%, l1_bound 47.78%]
# 10       [backend_bound 55.32%, memory_bound 10.58%, l1_bound 9.61%]
# 4       [backend_bound 65.27%, memory_bound 15.53%, l1_bound 14.70%]
# 44                                                 [retiring 53.42%]
# 45      [backend_bound 65.85%, memory_bound 71.88%, l1_bound 65.01%]
# 39                                                 [retiring 62.73%]
# 9                                                  [retiring 95.38%]
# 11                         [backend_bound 48.96%, core_bound 32.87%]
# 6         [backend_bound 51.40%, memory_bound 7.07%, l1_bound 5.36%]
# 2                  [frontend_bound 72.28%, frontend_latency 289.11%]
# 16                         [backend_bound 81.63%, core_bound 83.99%]
# 0   [backend_bound 48.12%, memory_bound 64.59%, uncore_bound 48.79%]
# 34      [backend_bound 66.34%, memory_bound 34.74%, l1_bound 33.40%]
# 38                         [backend_bound 55.48%, core_bound 29.81%]
# 40                                                 [retiring 71.16%]
# 43                                                 [retiring 53.10%]
# 10       [backend_bound 54.96%, memory_bound 10.55%, l1_bound 9.52%]
# 30                                                 [retiring 47.78%]
# 7       [backend_bound 55.43%, memory_bound 11.05%, l1_bound 10.13%]
# 23                                                 [retiring 56.32%]
# 36                         [backend_bound 66.23%, core_bound 20.18%]
# 25      [backend_bound 71.33%, memory_bound 16.83%, l1_bound 15.51%]
# 41      [backend_bound 59.30%, memory_bound 17.03%, l1_bound 11.84%]
# 4       [backend_bound 62.09%, memory_bound 16.38%, l1_bound 12.45%]
# 20      [backend_bound 69.83%, memory_bound 12.40%, l1_bound 10.01%]
# 29      [backend_bound 62.05%, memory_bound 17.34%, l1_bound 11.37%]
# 1       [backend_bound 65.72%, memory_bound 12.39%, l1_bound 10.93%]
# 15                                                [retiring 159.68%]
# 12                         [backend_bound 45.03%, core_bound 48.72%]
# 33                                                [retiring 131.24%]
# 56                                                 [retiring 53.67%]
# 47                                                 [retiring 53.03%]
# 48                                                 [retiring 53.52%]
# 34                         [backend_bound 48.59%, core_bound 33.99%]
# 35                         [backend_bound 82.23%, core_bound 85.40%]
# 28                          [backend_bound 55.66%, core_bound 4.11%]
# 39      [backend_bound 55.32%, memory_bound 10.75%, l1_bound 10.14%]
# 29                                                 [retiring 95.27%]
# 0                                                  [retiring 74.86%]
# 22                                                 [retiring 53.64%]
# 33                                                 [retiring 62.93%]
# 65                                                 [retiring 46.82%]
# 51                                                 [retiring 58.23%]
# 43       [backend_bound 54.71%, memory_bound 10.63%, l1_bound 9.59%]
# 30                                                 [retiring 90.40%]
# 16                                                 [retiring 62.46%]
# 41                                                 [retiring 64.95%]
# 42                                                 [retiring 47.76%]
# 50      [backend_bound 54.29%, memory_bound 55.00%, l1_bound 30.50%]
# 26                         [backend_bound 48.20%, core_bound 37.68%]
# 17                                                 [retiring 46.97%]
# 12                                                 [retiring 51.42%]
# 31                                                 [retiring 52.52%]
# 58                                                 [retiring 53.30%]
# 29                                                 [retiring 53.27%]
# 61                                                 [retiring 56.47%]
# 82                         [backend_bound 51.15%, core_bound 32.49%]
# 63        [backend_bound 56.43%, memory_bound 1.83%, l1_bound 0.96%]
# 43                                                 [retiring 53.99%]
# 39                                                 [retiring 53.48%]
# 54                                                 [retiring 94.15%]
# 37                                                 [retiring 53.64%]
# 75                                                 [retiring 53.87%]
# 71                                                 [retiring 61.39%]
# 7                                                  [retiring 54.00%]
# 76                         [backend_bound 49.63%, core_bound 30.80%]
# 1                                                  [retiring 64.16%]
# 74                                                 [retiring 56.49%]
# 81                                                 [retiring 53.44%]
# 14                                                 [retiring 53.36%]
# 63                                                 [retiring 54.03%]
# 47                                                 [retiring 63.11%]
# 2                                                  [retiring 91.68%]
# 83                                                 [retiring 47.69%]
# 23                                                 [retiring 53.62%]
# 59                                                 [retiring 53.44%]
# 36                                                 [retiring 53.17%]
# 78                                                 [retiring 53.11%]
# 25                                                 [retiring 62.62%]
# 54                         [backend_bound 58.69%, core_bound 43.09%]
# 69                                                 [retiring 63.13%]
# 85                                                 [retiring 53.66%]
# 90                                                 [retiring 53.17%]
# 30                                                 [retiring 53.65%]
# 15                                                 [retiring 53.38%]
# 47                                                 [retiring 53.62%]
# 71                                                 [retiring 53.75%]
#
#     memory_bound  l1_bound  l2_bound  l3_bound
# 0       0.163454  0.137907  0.003898  0.021210
# 13      0.185443  0.151520  0.003671  0.030098
# 6       0.118970  0.110911  0.004571  0.002979
# 14      0.168545  0.161756  0.001018  0.005548
# 12      0.149088  0.141534 -0.000045  0.006747
# 11      0.073193  0.054443  0.003145  0.015419
# 9       0.168471  0.156003  0.006754  0.005714
# 7       0.622959  0.314746 -0.134761  0.174897
# 1       1.289460  0.686002  0.071766  0.127417
# 5       0.351969  0.330192  0.001093  0.015224
# 2       0.142262  0.108707  0.009489  0.022993
# 0       0.770185  0.477757  0.025426  0.267001
# 10      0.105794  0.096108  0.004712  0.004973
# 4       0.155319  0.146966  0.005793  0.002560
# 44      0.118115  0.110172  0.004601  0.002942
# 45      0.718801  0.650150 -0.017045  0.011030
# 39      0.000000 -0.003930  0.003016  0.000909
# 9       0.006514  0.000988  0.003277  0.001045
# 11      0.180865  0.165235 -0.000203  0.013846
# 6       0.070712  0.053645  0.002903  0.013981
# 2       0.311329  0.274118  0.008011  0.029100
# 16      0.246026  0.184536  0.011602  0.016586
# 0       0.645916  0.312159 -0.154107  0.184342
# 34      0.347404  0.334006  0.000611  0.012087
# 38      0.233320  0.130255  0.021011  0.081114
# 40      0.084782  0.051198  0.002093  0.031462
# 43      0.021672  0.015787  0.005885  0.000000
# 10      0.105465  0.095185  0.004489  0.005791
# 30      0.179707  0.117657  0.015224  0.046711
# 7       0.110456  0.101310  0.005784  0.003363
# 23      0.224942  0.169888  0.011318  0.043736
# 36      0.129717  0.114487  0.008141  0.007089
# 25      0.168287  0.155076  0.006994  0.006216
# 41      0.170282  0.118372  0.011540  0.040369
# 4       0.163783  0.124476  0.011314  0.027993
# 20      0.124045  0.100093 -0.005962  0.029914
# 29      0.173379  0.113692  0.014911  0.044775
# 1       0.123933  0.109297 -0.000600  0.015237
# 15      0.000000  0.000000  0.000000  0.000000
# 12      0.192036  0.099128  0.031536  0.058117
# 33      0.000000  0.000000  0.000000  0.000000
# 56      0.119964  0.113074  0.003966  0.002829
# 47      0.115861  0.106456  0.005521  0.003023
# 48      0.114508  0.105815  0.004903  0.003538
# 34      0.178832  0.167580 -0.000698  0.009860
# 35      0.248061  0.189065  0.010859  0.015093
# 28      0.038029  0.019415  0.003824  0.014559
# 39      0.107505  0.101430  0.000335  0.005667
# 29      0.006423  0.000797  0.003312  0.001278
# 0       0.059411  0.038138  0.000678  0.020595
# 22      0.009249  0.005280  0.003969  0.000000
# 33      0.000000 -0.003304  0.002673  0.000625
# 65      0.262507  0.178363  0.017208  0.066243
# 51      0.054174  0.001437  0.026651  0.000000
# 43      0.106267  0.095855  0.004121  0.006291
# 30      0.000000  0.000000  0.000000  0.000000
# 16      0.000000 -0.003260  0.002376  0.000884
# 41      0.000000 -0.003492  0.002840  0.000652
# 42      0.027416  0.016320  0.006590  0.001453
# 50      0.550033  0.304967 -0.044648  0.265513
# 26      0.118122  0.065142  0.020372  0.031700
# 17      0.024344  0.017444  0.005354  0.001546
# 12      0.025100  0.017895  0.004842  0.002363
# 31      0.024543  0.019628  0.003163  0.001752
# 58      0.113434  0.105704  0.004479  0.003156
# 29      0.115897  0.106917  0.005410  0.002776
# 61      0.170806  0.170467 -0.000024  0.000255
# 82      0.042986 -0.013019  0.022949  0.000000
# 63      0.018304  0.009552  0.001213  0.007432
# 43      0.111752  0.104820  0.004550  0.002293
# 39      0.115223  0.105973  0.005041  0.004081
# 54      0.006743  0.000532  0.003488  0.001409
# 37      0.000000 -0.004152  0.004152  0.000000
# 75      0.112476  0.103777  0.005177  0.003426
# 71      0.000000 -0.003099  0.002710  0.000375
# 7       0.000000 -0.001940  0.001940  0.000000
# 76      0.154532  0.087242  0.020901  0.043827
# 1       0.000000 -0.001674  0.001408  0.000265
# 74      0.170392  0.170162 -0.000005  0.000128
# 81      0.112503  0.105585  0.004315  0.002519
# 14      0.114173  0.106257  0.005560  0.001628
# 63      0.111133  0.104414  0.004462  0.002165
# 47      0.024614  0.018163  0.005339  0.000845
# 2       0.007298  0.001754  0.003183  0.000958
# 83      0.153730  0.117296  0.010495  0.025643
# 23      0.112162  0.105559  0.004214  0.002297
# 59      0.112364  0.105537  0.004298  0.002456
# 36      0.112526  0.105445  0.004398  0.002598
# 78      0.112481  0.105307  0.004418  0.002715
# 25      0.024334  0.016665  0.006505  0.000724
# 54      0.000000 -0.042341 -0.000692  0.012955
# 69      0.022996  0.017873  0.004670  0.000453
# 85      0.112044  0.105458  0.004230  0.002261
# 90      0.111637  0.104760  0.004543  0.002258
# 30      0.111459  0.105273  0.004103  0.002010
# 15      0.112407  0.105567  0.004236  0.002548
# 47      0.112065  0.105379  0.004169  0.002439
# 71      0.111491  0.105106  0.004113  0.002175

# %% [markdown]
# # Analyze the "call tree"
# Visualize the aggregated tree with topdown metrics

# %%
tree = hatchet.Tree(mrt.roots[0])
tree
# Out:
# {
#     "hash#function": 1128851083484916900,
#     "time.inclusive.duration": 37213720.0,
#     "cali.caliper.version": 15,
#     "function": [
#         "main"
#     ],
#     "parent_hash#function": 3527539,
#     "depth#function": 1,
#     "retiring": 0.4884572575,
#     "bad_speculation": 0.0177889881,
#     "frontend_bound": 0.0987573261,
#     "backend_bound": 0.3949964282,
#     "branch_mispredict": 0.9716684103,
#     "machine_clear": 0.0283315897,
#     "frontend_latency": 0.3950293045,
#     "frontend_bandwidth": 0.6049706955,
#     "memory_bound": 0.1634543727,
#     "core_bound": 0.2507063494,
#     "mem_bound": 0.0004396511,
#     "l1_bound": 0.1379074174,
#     "l2_bound": 0.0038977746,
#     "l3_bound": 0.0212095295,
#     "uncore_bound": 0.0216491806,
#     "boundedness": [
#         "retiring 48.85%"
#     ],
#     "children": [
#         {
#             "hash#function": -8404990865778211590,
#             "time.inclusive.duration": 341.0,
#             "cali.caliper.version": 2,
#             "function": [
#                 "main",
#                 "printParameters"
#             ],
#             "parent_hash#function": 1128851083484916900,
#             "depth#function": 2,
#             "retiring": 0.2616456192,
#             "bad_speculation": -0.0803929383,
#             "frontend_bound": 0.172819064,
#             "backend_bound": 0.6459282551,
#             "branch_mispredict": 0.9784172662,
#             "machine_clear": 0.0215827338,
#             "frontend_latency": 0.6912762558,
#             "frontend_bandwidth": 0.3087237442,
#             "memory_bound": 0.770184783,
#             "core_bound": 0.474356333,
#             "mem_bound": 0.0,
#             "l1_bound": 0.4777574753,
#             "l2_bound": 0.0254258183,
#             "l3_bound": 0.2670014895,
#             "uncore_bound": 0.2670014895,
#             "boundedness": [
#                 "backend_bound 64.59%",
#                 "memory_bound 77.02%",
#                 "l1_bound 47.78%"
#             ],
#             "children": [
#                 {
#                     "hash#function": 1327647275769230351,
#                     "time.inclusive.duration": 61.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "printParameters",
#                         "operator<<"
#                     ],
#                     "parent_hash#function": -8404990865778211590,
#                     "depth#function": 3,
#                     "retiring": null,
#                     "bad_speculation": null,
#                     "frontend_bound": null,
#                     "backend_bound": null,
#                     "branch_mispredict": null,
#                     "machine_clear": null,
#                     "frontend_latency": null,
#                     "frontend_bandwidth": null,
#                     "memory_bound": null,
#                     "core_bound": null,
#                     "mem_bound": null,
#                     "l1_bound": null,
#                     "l2_bound": null,
#                     "l3_bound": null,
#                     "uncore_bound": null,
#                     "boundedness": [
#                         "undetermined"
#                     ]
#                 }
#             ]
#         },
#         {
#             "hash#function": -7516306253691115888,
#             "time.inclusive.duration": 618.0,
#             "cali.caliper.version": 1,
#             "function": [
#                 "main",
#                 "~MonteCarlo"
#             ],
#             "parent_hash#function": 1128851083484916900,
#             "depth#function": 2,
#             "retiring": 0.1291901343,
#             "bad_speculation": 0.0220553779,
#             "frontend_bound": 0.2313364681,
#             "backend_bound": 0.6174180197,
#             "branch_mispredict": 0.9102564103,
#             "machine_clear": 0.0897435897,
#             "frontend_latency": 0.9253458725,
#             "frontend_bandwidth": 0.0746541275,
#             "memory_bound": 1.2894604706,
#             "core_bound": -0.1027093474,
#             "mem_bound": 0.4042759005,
#             "l1_bound": 0.6860015357,
#             "l2_bound": 0.071766495,
#             "l3_bound": 0.1274165394,
#             "uncore_bound": 0.5316924399,
#             "boundedness": [
#                 "backend_bound 61.74%",
#                 "memory_bound 128.95%",
#                 "l1_bound 68.60%"
#             ]
#         },
#         {
#             "hash#function": -5143781023991094254,
#             "time.inclusive.duration": 503.0,
#             "cali.caliper.version": 2,
#             "function": [
#                 "main",
#                 "processArgs"
#             ],
#             "parent_hash#function": 1128851083484916900,
#             "depth#function": 2,
#             "retiring": 0.2115548349,
#             "bad_speculation": -0.0989587622,
#             "frontend_bound": 0.2489540508,
#             "backend_bound": 0.6384498764,
#             "branch_mispredict": 0.8671747414,
#             "machine_clear": 0.1328252586,
#             "frontend_latency": 0.9958162033,
#             "frontend_bandwidth": 0.0041837967,
#             "memory_bound": 0.142261511,
#             "core_bound": 0.2139822959,
#             "mem_bound": 0.0010719723,
#             "l1_bound": 0.1087073795,
#             "l2_bound": 0.009489448,
#             "l3_bound": 0.0229927113,
#             "uncore_bound": 0.0240646836,
#             "boundedness": [
#                 "backend_bound 63.84%",
#                 "core_bound 21.40%"
#             ],
#             "children": [
#                 {
#                     "hash#function": 4948303505321721652,
#                     "time.inclusive.duration": 51.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "processArgs",
#                         "findOption"
#                     ],
#                     "parent_hash#function": -5143781023991094254,
#                     "depth#function": 3,
#                     "retiring": 0.2205706413,
#                     "bad_speculation": -0.1066560993,
#                     "frontend_bound": 0.2237908622,
#                     "backend_bound": 0.6622945958,
#                     "branch_mispredict": 0.7940613027,
#                     "machine_clear": 0.2059386973,
#                     "frontend_latency": 0.8951634488,
#                     "frontend_bandwidth": 0.1048365512,
#                     "memory_bound": 0.1297167448,
#                     "core_bound": 0.2017636981,
#                     "mem_bound": 0.0,
#                     "l1_bound": 0.1144867003,
#                     "l2_bound": 0.0081412939,
#                     "l3_bound": 0.0070887505,
#                     "uncore_bound": 0.0070887505,
#                     "boundedness": [
#                         "backend_bound 66.23%",
#                         "core_bound 20.18%"
#                     ]
#                 }
#             ]
#         },
#         {
#             "hash#function": -3675806031077117392,
#             "time.inclusive.duration": 54.0,
#             "cali.caliper.version": 1,
#             "function": [
#                 "main",
#                 "printBanner"
#             ],
#             "parent_hash#function": 1128851083484916900,
#             "depth#function": 2,
#             "retiring": 0.2008561283,
#             "bad_speculation": 0.0236097093,
#             "frontend_bound": 0.0401281038,
#             "backend_bound": 0.7354060586,
#             "branch_mispredict": 1.0,
#             "machine_clear": 0.0,
#             "frontend_latency": 0.1605124154,
#             "frontend_bandwidth": 0.8394875846,
#             "memory_bound": 0.0358593546,
#             "core_bound": 0.4131038605,
#             "mem_bound": null,
#             "l1_bound": -0.0816667149,
#             "l2_bound": -0.0195051229,
#             "l3_bound": null,
#             "uncore_bound": 0.1370311925,
#             "boundedness": [
#                 "backend_bound 73.54%",
#                 "core_bound 41.31%"
#             ]
#         },
#         {
#             "hash#function": -3660262160707739778,
#             "time.inclusive.duration": 43.0,
#             "cali.caliper.version": 1,
#             "function": [
#                 "main",
#                 "supplyDefaults"
#             ],
#             "parent_hash#function": 1128851083484916900,
#             "depth#function": 2,
#             "retiring": 0.2908562708,
#             "bad_speculation": -0.1077182081,
#             "frontend_bound": 0.1641291181,
#             "backend_bound": 0.6527328192,
#             "branch_mispredict": 0.96875,
#             "machine_clear": 0.03125,
#             "frontend_latency": 0.6565164725,
#             "frontend_bandwidth": 0.3434835275,
#             "memory_bound": 0.1553188432,
#             "core_bound": -0.0064398243,
#             "mem_bound": 0.0,
#             "l1_bound": 0.1469662337,
#             "l2_bound": 0.0057931044,
#             "l3_bound": 0.0025595051,
#             "uncore_bound": 0.0025595051,
#             "boundedness": [
#                 "backend_bound 65.27%",
#                 "memory_bound 15.53%",
#                 "l1_bound 14.70%"
#             ]
#         },
#         {
#             "hash#function": -2281267291879510595,
#             "time.inclusive.duration": 598.0,
#             "cali.caliper.version": 5,
#             "function": [
#                 "main",
#                 "coralBenchmarkCorrectness"
#             ],
#             "parent_hash#function": 1128851083484916900,
#             "depth#function": 2,
#             "retiring": 0.3886949507,
#             "bad_speculation": -0.1121788169,
#             "frontend_bound": 0.0679250053,
#             "backend_bound": 0.655558861,
#             "branch_mispredict": 0.9724296381,
#             "machine_clear": 0.0275703619,
#             "frontend_latency": 0.271700021,
#             "frontend_bandwidth": 0.728299979,
#             "memory_bound": 0.3519687415,
#             "core_bound": 0.0120277995,
#             "mem_bound": 0.0054595552,
#             "l1_bound": 0.3301916041,
#             "l2_bound": 0.0010932224,
#             "l3_bound": 0.0152243597,
#             "uncore_bound": 0.0206839149,
#             "boundedness": [
#                 "backend_bound 65.56%",
#                 "memory_bound 35.20%",
#                 "l1_bound 33.02%"
#             ],
#             "children": [
#                 {
#                     "hash#function": -7966588181912298134,
#                     "time.inclusive.duration": 19.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "coralBenchmarkCorrectness",
#                         "BalanceEventTest"
#                     ],
#                     "parent_hash#function": -2281267291879510595,
#                     "depth#function": 3,
#                     "retiring": null,
#                     "bad_speculation": null,
#                     "frontend_bound": null,
#                     "backend_bound": null,
#                     "branch_mispredict": null,
#                     "machine_clear": null,
#                     "frontend_latency": null,
#                     "frontend_bandwidth": null,
#                     "memory_bound": null,
#                     "core_bound": null,
#                     "mem_bound": null,
#                     "l1_bound": null,
#                     "l2_bound": null,
#                     "l3_bound": null,
#                     "uncore_bound": null,
#                     "boundedness": [
#                         "undetermined"
#                     ]
#                 },
#                 {
#                     "hash#function": -3542227746260778691,
#                     "time.inclusive.duration": 45.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "coralBenchmarkCorrectness",
#                         "BalanceRatioTest"
#                     ],
#                     "parent_hash#function": -2281267291879510595,
#                     "depth#function": 3,
#                     "retiring": null,
#                     "bad_speculation": null,
#                     "frontend_bound": null,
#                     "backend_bound": null,
#                     "branch_mispredict": null,
#                     "machine_clear": null,
#                     "frontend_latency": null,
#                     "frontend_bandwidth": null,
#                     "memory_bound": null,
#                     "core_bound": null,
#                     "mem_bound": null,
#                     "l1_bound": null,
#                     "l2_bound": null,
#                     "l3_bound": null,
#                     "uncore_bound": null,
#                     "boundedness": [
#                         "undetermined"
#                     ]
#                 },
#                 {
#                     "hash#function": -829749220284175990,
#                     "time.inclusive.duration": 18.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "coralBenchmarkCorrectness",
#                         "MissingParticleTest"
#                     ],
#                     "parent_hash#function": -2281267291879510595,
#                     "depth#function": 3,
#                     "retiring": null,
#                     "bad_speculation": null,
#                     "frontend_bound": null,
#                     "backend_bound": null,
#                     "branch_mispredict": null,
#                     "machine_clear": null,
#                     "frontend_latency": null,
#                     "frontend_bandwidth": null,
#                     "memory_bound": null,
#                     "core_bound": null,
#                     "mem_bound": null,
#                     "l1_bound": null,
#                     "l2_bound": null,
#                     "l3_bound": null,
#                     "uncore_bound": null,
#                     "boundedness": [
#                         "undetermined"
#                     ]
#                 },
#                 {
#                     "hash#function": 4399659537923052962,
#                     "time.inclusive.duration": 563.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "coralBenchmarkCorrectness",
#                         "FluenceTest"
#                     ],
#                     "parent_hash#function": -2281267291879510595,
#                     "depth#function": 3,
#                     "retiring": 0.3915396533,
#                     "bad_speculation": -0.1125530969,
#                     "frontend_bound": 0.0576174662,
#                     "backend_bound": 0.6633959774,
#                     "branch_mispredict": 0.9828025478,
#                     "machine_clear": 0.0171974522,
#                     "frontend_latency": 0.2304698649,
#                     "frontend_bandwidth": 0.7695301351,
#                     "memory_bound": 0.3474043144,
#                     "core_bound": 0.0188468406,
#                     "mem_bound": 0.0007008215,
#                     "l1_bound": 0.3340060444,
#                     "l2_bound": 0.0006105534,
#                     "l3_bound": 0.0120868952,
#                     "uncore_bound": 0.0127877167,
#                     "boundedness": [
#                         "backend_bound 66.34%",
#                         "memory_bound 34.74%",
#                         "l1_bound 33.40%"
#                     ]
#                 }
#             ]
#         },
#         {
#             "hash#function": -611320776416371186,
#             "time.inclusive.duration": 2829809.0,
#             "cali.caliper.version": 8,
#             "function": [
#                 "main",
#                 "initMC"
#             ],
#             "parent_hash#function": 1128851083484916900,
#             "depth#function": 2,
#             "retiring": 0.5337066697,
#             "bad_speculation": 0.0069620454,
#             "frontend_bound": 0.1423256816,
#             "backend_bound": 0.3170056033,
#             "branch_mispredict": 0.8602205522,
#             "machine_clear": 0.1397794478,
#             "frontend_latency": 0.5693027263,
#             "frontend_bandwidth": 0.4306972737,
#             "memory_bound": 0.118970396,
#             "core_bound": 0.2536315758,
#             "mem_bound": 0.0005083315,
#             "l1_bound": 0.1109113511,
#             "l2_bound": 0.0045714328,
#             "l3_bound": 0.0029792806,
#             "uncore_bound": 0.0034876121,
#             "boundedness": [
#                 "retiring 53.37%"
#             ],
#             "children": [
#                 {
#                     "hash#function": -6869053137859240812,
#                     "time.inclusive.duration": 3690.0,
#                     "cali.caliper.version": 3,
#                     "function": [
#                         "main",
#                         "initMC",
#                         "initNuclearData"
#                     ],
#                     "parent_hash#function": -611320776416371186,
#                     "depth#function": 3,
#                     "retiring": 0.9537602294,
#                     "bad_speculation": 0.1254151,
#                     "frontend_bound": 0.0282188407,
#                     "backend_bound": -0.10739417,
#                     "branch_mispredict": 0.9545638819,
#                     "machine_clear": 0.0454361181,
#                     "frontend_latency": 0.1128753628,
#                     "frontend_bandwidth": 0.8871246372,
#                     "memory_bound": 0.0065141634,
#                     "core_bound": 0.5673780303,
#                     "mem_bound": 0.0012043546,
#                     "l1_bound": 0.0009883902,
#                     "l2_bound": 0.0032768884,
#                     "l3_bound": 0.0010445302,
#                     "uncore_bound": 0.0022488847,
#                     "boundedness": [
#                         "retiring 95.38%"
#                     ],
#                     "children": [
#                         {
#                             "hash#function": -2868132710735568508,
#                             "time.inclusive.duration": 385.0,
#                             "cali.caliper.version": 2,
#                             "function": [
#                                 "main",
#                                 "initMC",
#                                 "initNuclearData",
#                                 "addIsotope"
#                             ],
#                             "parent_hash#function": -6869053137859240812,
#                             "depth#function": 4,
#                             "retiring": 0.9527081189,
#                             "bad_speculation": 0.1189657537,
#                             "frontend_bound": 0.0248000793,
#                             "backend_bound": -0.096473952,
#                             "branch_mispredict": 0.9592185191,
#                             "machine_clear": 0.0407814809,
#                             "frontend_latency": 0.0992003172,
#                             "frontend_bandwidth": 0.9007996828,
#                             "memory_bound": 0.0064231143,
#                             "core_bound": 0.5589567057,
#                             "mem_bound": 0.0010351899,
#                             "l1_bound": 0.0007971724,
#                             "l2_bound": 0.0033123004,
#                             "l3_bound": 0.0012784516,
#                             "uncore_bound": 0.0023136415,
#                             "boundedness": [
#                                 "retiring 95.27%"
#                             ],
#                             "children": [
#                                 {
#                                     "hash#function": 1578644897819887607,
#                                     "time.inclusive.duration": 127.0,
#                                     "cali.caliper.version": 2,
#                                     "function": [
#                                         "main",
#                                         "initMC",
#                                         "initNuclearData",
#                                         "addIsotope",
#                                         "addReaction"
#                                     ],
#                                     "parent_hash#function": -2868132710735568508,
#                                     "depth#function": 5,
#                                     "retiring": 0.9415276471,
#                                     "bad_speculation": 0.1252577603,
#                                     "frontend_bound": 0.0234540551,
#                                     "backend_bound": -0.0902394624,
#                                     "branch_mispredict": 0.9652157738,
#                                     "machine_clear": 0.0347842262,
#                                     "frontend_latency": 0.0938162205,
#                                     "frontend_bandwidth": 0.9061837795,
#                                     "memory_bound": 0.0067427683,
#                                     "core_bound": 0.5726762135,
#                                     "mem_bound": 0.0013139357,
#                                     "l1_bound": 0.0005323623,
#                                     "l2_bound": 0.0034879139,
#                                     "l3_bound": 0.0014085565,
#                                     "uncore_bound": 0.0027224922,
#                                     "boundedness": [
#                                         "retiring 94.15%"
#                                     ],
#                                     "children": [
#                                         {
#                                             "hash#function": -8885906963766464142,
#                                             "time.inclusive.duration": 77.0,
#                                             "cali.caliper.version": 1,
#                                             "function": [
#                                                 "main",
#                                                 "initMC",
#                                                 "initNuclearData",
#                                                 "addIsotope",
#                                                 "addReaction",
#                                                 "NuclearDataReaction"
#                                             ],
#                                             "parent_hash#function": 1578644897819887607,
#                                             "depth#function": 6,
#                                             "retiring": 0.9168039823,
#                                             "bad_speculation": 0.1507713481,
#                                             "frontend_bound": 0.017238709,
#                                             "backend_bound": -0.0848140395,
#                                             "branch_mispredict": 0.9801505174,
#                                             "machine_clear": 0.0198494826,
#                                             "frontend_latency": 0.0689548361,
#                                             "frontend_bandwidth": 0.9310451639,
#                                             "memory_bound": 0.0072977456,
#                                             "core_bound": 0.6265228204,
#                                             "mem_bound": 0.0014030007,
#                                             "l1_bound": 0.0017537717,
#                                             "l2_bound": 0.0031828439,
#                                             "l3_bound": 0.0009581293,
#                                             "uncore_bound": 0.00236113,
#                                             "boundedness": [
#                                                 "retiring 91.68%"
#                                             ]
#                                         }
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "hash#function": -2636625441205944096,
#                             "time.inclusive.duration": 46.0,
#                             "cali.caliper.version": 1,
#                             "function": [
#                                 "main",
#                                 "initMC",
#                                 "initNuclearData",
#                                 "NuclearData"
#                             ],
#                             "parent_hash#function": -6869053137859240812,
#                             "depth#function": 4,
#                             "retiring": 0.9039514506,
#                             "bad_speculation": 0.7433265754,
#                             "frontend_bound": 0.2963741572,
#                             "backend_bound": -0.9436521833,
#                             "branch_mispredict": 0.5803571429,
#                             "machine_clear": 0.4196428571,
#                             "frontend_latency": 1.1854966287,
#                             "frontend_bandwidth": -0.1854966287,
#                             "memory_bound": 0.0,
#                             "core_bound": 1.6202982691,
#                             "mem_bound": 0.0,
#                             "l1_bound": 0.0,
#                             "l2_bound": 0.0,
#                             "l3_bound": 0.0,
#                             "uncore_bound": 0.0,
#                             "boundedness": [
#                                 "retiring 90.40%"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "hash#function": -5977368937476155790,
#                     "time.inclusive.duration": 19.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "initMC",
#                         "checkCrossSections"
#                     ],
#                     "parent_hash#function": -611320776416371186,
#                     "depth#function": 3,
#                     "retiring": 0.3100856621,
#                     "bad_speculation": 0.1729885124,
#                     "frontend_bound": 0.0665816059,
#                     "backend_bound": 0.4503442196,
#                     "branch_mispredict": 0.9282051282,
#                     "machine_clear": 0.0717948718,
#                     "frontend_latency": 0.2663264237,
#                     "frontend_bandwidth": 0.7336735763,
#                     "memory_bound": 0.1920355218,
#                     "core_bound": 0.4871914245,
#                     "mem_bound": 0.0032545629,
#                     "l1_bound": 0.0991282487,
#                     "l2_bound": 0.031535516,
#                     "l3_bound": 0.0581171942,
#                     "uncore_bound": 0.0613717571,
#                     "boundedness": [
#                         "backend_bound 45.03%",
#                         "core_bound 48.72%"
#                     ]
#                 },
#                 {
#                     "hash#function": -4105785887040771043,
#                     "time.inclusive.duration": 22.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "initMC",
#                         "initTimeInfo"
#                     ],
#                     "parent_hash#function": -611320776416371186,
#                     "depth#function": 3,
#                     "retiring": 1.5968363959,
#                     "bad_speculation": 1.1188723216,
#                     "frontend_bound": 0.3285951453,
#                     "backend_bound": -2.0443038627,
#                     "branch_mispredict": 0.612244898,
#                     "machine_clear": 0.387755102,
#                     "frontend_latency": 1.3143805812,
#                     "frontend_bandwidth": -0.3143805812,
#                     "memory_bound": 0.0,
#                     "core_bound": 1.7550372249,
#                     "mem_bound": 0.0,
#                     "l1_bound": 0.0,
#                     "l2_bound": 0.0,
#                     "l3_bound": 0.0,
#                     "uncore_bound": 0.0,
#                     "boundedness": [
#                         "retiring 159.68%"
#                     ]
#                 },
#                 {
#                     "hash#function": -3683832412712394459,
#                     "time.inclusive.duration": 1377.0,
#                     "cali.caliper.version": 2,
#                     "function": [
#                         "main",
#                         "initMC",
#                         "initTallies"
#                     ],
#                     "parent_hash#function": -611320776416371186,
#                     "depth#function": 3,
#                     "retiring": 0.1387918828,
#                     "bad_speculation": 0.0202332302,
#                     "frontend_bound": 0.0246304866,
#                     "backend_bound": 0.8163444004,
#                     "branch_mispredict": 0.7250575442,
#                     "machine_clear": 0.2749424558,
#                     "frontend_latency": 0.0985219462,
#                     "frontend_bandwidth": 0.9014780538,
#                     "memory_bound": 0.2460255043,
#                     "core_bound": 0.8399388505,
#                     "mem_bound": 0.0333016511,
#                     "l1_bound": 0.1845362746,
#                     "l2_bound": 0.0116019378,
#                     "l3_bound": 0.0165856408,
#                     "uncore_bound": 0.0498872919,
#                     "boundedness": [
#                         "backend_bound 81.63%",
#                         "core_bound 83.99%"
#                     ],
#                     "children": [
#                         {
#                             "hash#function": -840986241129762178,
#                             "time.inclusive.duration": 1325.0,
#                             "cali.caliper.version": 1,
#                             "function": [
#                                 "main",
#                                 "initMC",
#                                 "initTallies",
#                                 "InitializeTallies"
#                             ],
#                             "parent_hash#function": -3683832412712394459,
#                             "depth#function": 4,
#                             "retiring": 0.1352596995,
#                             "bad_speculation": 0.0185799798,
#                             "frontend_bound": 0.0238566334,
#                             "backend_bound": 0.8223036873,
#                             "branch_mispredict": 0.7198405597,
#                             "machine_clear": 0.2801594403,
#                             "frontend_latency": 0.0954265334,
#                             "frontend_bandwidth": 0.9045734666,
#                             "memory_bound": 0.2480608645,
#                             "core_bound": 0.8540382088,
#                             "mem_bound": 0.0330441491,
#                             "l1_bound": 0.1890651553,
#                             "l2_bound": 0.0108585538,
#                             "l3_bound": 0.0150930062,
#                             "uncore_bound": 0.0481371554,
#                             "boundedness": [
#                                 "backend_bound 82.23%",
#                                 "core_bound 85.40%"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "hash#function": 3974207558341453912,
#                     "time.inclusive.duration": 19.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "initMC",
#                         "initGPUInfo"
#                     ],
#                     "parent_hash#function": -611320776416371186,
#                     "depth#function": 3,
#                     "retiring": 1.3123770269,
#                     "bad_speculation": 0.9296890902,
#                     "frontend_bound": 0.3017589389,
#                     "backend_bound": -1.543825056,
#                     "branch_mispredict": 0.7878787879,
#                     "machine_clear": 0.2121212121,
#                     "frontend_latency": 1.2070357555,
#                     "frontend_bandwidth": -0.2070357555,
#                     "memory_bound": 0.0,
#                     "core_bound": 1.5197435376,
#                     "mem_bound": 0.0,
#                     "l1_bound": 0.0,
#                     "l2_bound": 0.0,
#                     "l3_bound": 0.0,
#                     "uncore_bound": 0.0,
#                     "boundedness": [
#                         "retiring 131.24%"
#                     ]
#                 },
#                 {
#                     "hash#function": 8826531664285963129,
#                     "time.inclusive.duration": 2816012.0,
#                     "cali.caliper.version": 9,
#                     "function": [
#                         "main",
#                         "initMC",
#                         "initMesh"
#                     ],
#                     "parent_hash#function": -611320776416371186,
#                     "depth#function": 3,
#                     "retiring": 0.5342087471,
#                     "bad_speculation": 0.0067469155,
#                     "frontend_bound": 0.1424069379,
#                     "backend_bound": 0.3166373996,
#                     "branch_mispredict": 0.8637140762,
#                     "machine_clear": 0.1362859238,
#                     "frontend_latency": 0.5696277515,
#                     "frontend_bandwidth": 0.4303722485,
#                     "memory_bound": 0.1181150035,
#                     "core_bound": 0.2528094288,
#                     "mem_bound": 0.0003999025,
#                     "l1_bound": 0.1101718044,
#                     "l2_bound": 0.0046008842,
#                     "l3_bound": 0.0029424124,
#                     "uncore_bound": 0.0033423148,
#                     "boundedness": [
#                         "retiring 53.42%"
#                     ],
#                     "children": [
#                         {
#                             "hash#function": -6719108034352903137,
#                             "time.inclusive.duration": 19.0,
#                             "cali.caliper.version": 1,
#                             "function": [
#                                 "main",
#                                 "initMC",
#                                 "initMesh",
#                                 "MpiCommObject"
#                             ],
#                             "parent_hash#function": 8826531664285963129,
#                             "depth#function": 4,
#                             "retiring": 0.5141571847,
#                             "bad_speculation": 0.1111481976,
#                             "frontend_bound": 0.0,
#                             "backend_bound": 0.3746946177,
#                             "branch_mispredict": 0.974522293,
#                             "machine_clear": 0.025477707,
#                             "frontend_latency": 1.59417e-05,
#                             "frontend_bandwidth": 0.9999840583,
#                             "memory_bound": 0.0251001335,
#                             "core_bound": 0.5360659984,
#                             "mem_bound": 0.0,
#                             "l1_bound": 0.0178945061,
#                             "l2_bound": 0.0048422773,
#                             "l3_bound": 0.0023633501,
#                             "uncore_bound": 0.0023633501,
#                             "boundedness": [
#                                 "retiring 51.42%"
#                             ]
#                         },
#                         {
#                             "hash#function": -5842126017516600213,
#                             "time.inclusive.duration": 23.0,
#                             "cali.caliper.version": 1,
#                             "function": [
#                                 "main",
#                                 "initMC",
#                                 "initMesh",
#                                 "DecompositionObject"
#                             ],
#                             "parent_hash#function": 8826531664285963129,
#                             "depth#function": 4,
#                             "retiring": 0.4697048375,
#                             "bad_speculation": 0.2203434264,
#                             "frontend_bound": 0.0,
#                             "backend_bound": 0.3099517361,
#                             "branch_mispredict": 0.9977220957,
#                             "machine_clear": 0.0022779043,
#                             "frontend_latency": 1.3444e-05,
#                             "frontend_bandwidth": 0.999986556,
#                             "memory_bound": 0.0243436818,
#                             "core_bound": 0.5194820036,
#                             "mem_bound": 0.0,
#                             "l1_bound": 0.0174435605,
#                             "l2_bound": 0.0053540639,
#                             "l3_bound": 0.0015460574,
#                             "uncore_bound": 0.0015460574,
#                             "boundedness": [
#                                 "retiring 46.97%"
#                             ]
#                         },
#                         {
#                             "hash#function": -2298234743521158357,
#                             "time.inclusive.duration": 19.0,
#                             "cali.caliper.version": 1,
#                             "function": [
#                                 "main",
#                                 "initMC",
#                                 "initMesh",
#                                 "MeshPartition"
#                             ],
#                             "parent_hash#function": 8826531664285963129,
#                             "depth#function": 4,
#                             "retiring": 0.5251523241,
#                             "bad_speculation": 0.1139893628,
#                             "frontend_bound": 0.0,
#                             "backend_bound": 0.3608583131,
#                             "branch_mispredict": 0.9854014599,
#                             "machine_clear": 0.0145985401,
#                             "frontend_latency": 1.63022e-05,
#                             "frontend_bandwidth": 0.9999836978,
#                             "memory_bound": 0.0245430277,
#                             "core_bound": 0.5303853443,
#                             "mem_bound": 0.0,
#                             "l1_bound": 0.0196279013,
#                             "l2_bound": 0.0031626353,
#                             "l3_bound": 0.0017524912,
#                             "uncore_bound": 0.0017524912,
#                             "boundedness": [
#                                 "retiring 52.52%"
#                             ]
#                         },
#                         {
#                             "hash#function": -287008821822730623,
#                             "time.inclusive.duration": 28.0,
#                             "cali.caliper.version": 1,
#                             "function": [
#                                 "main",
#                                 "initMC",
#                                 "initMesh",
#                                 "initializeCentersGrid"
#                             ],
#                             "parent_hash#function": 8826531664285963129,
#                             "depth#function": 4,
#                             "retiring": 0.4775785666,
#                             "bad_speculation": 0.1456955166,
#                             "frontend_bound": 0.0,
#                             "backend_bound": 0.3767259168,
#                             "branch_mispredict": 0.9904942966,
#                             "machine_clear": 0.0095057034,
#                             "frontend_latency": 1.41577e-05,
#                             "frontend_bandwidth": 0.9999858423,
#                             "memory_bound": 0.0274164605,
#                             "core_bound": 0.5138621957,
#                             "mem_bound": 0.0030522486,
#                             "l1_bound": 0.016320333,
#                             "l2_bound": 0.0065904272,
#                             "l3_bound": 0.0014534517,
#                             "uncore_bound": 0.0045057003,
#                             "boundedness": [
#                                 "retiring 47.76%"
#                             ]
#                         },
#                         {
#                             "hash#function": 1551109911967735083,
#                             "time.inclusive.duration": 1058573.0,
#                             "cali.caliper.version": 3,
#                             "function": [
#                                 "main",
#                                 "initMC",
#                                 "initMesh",
#                                 "MC_Mesh_Domain"
#                             ],
#                             "parent_hash#function": 8826531664285963129,
#                             "depth#function": 4,
#                             "retiring": 0.5303079484,
#                             "bad_speculation": 0.005689637,
#                             "frontend_bound": 0.1484516078,
#                             "backend_bound": 0.3155508068,
#                             "branch_mispredict": 0.8503674832,
#                             "machine_clear": 0.1496325168,
#                             "frontend_latency": 0.5938064311,
#                             "frontend_bandwidth": 0.4061935689,
#                             "memory_bound": 0.1158608169,
#                             "core_bound": 0.2512529663,
#                             "mem_bound": 0.0008609338,
#                             "l1_bound": 0.1064562388,
#                             "l2_bound": 0.0055209269,
#                             "l3_bound": 0.0030227174,
#                             "uncore_bound": 0.0038836512,
#                             "boundedness": [
#                                 "retiring 53.03%"
#                             ],
#                             "children": [
#                                 {
#                                     "hash#function": -3346546285056646112,
#                                     "time.inclusive.duration": 1053554.0,
#                                     "cali.caliper.version": 2,
#                                     "function": [
#                                         "main",
#                                         "initMC",
#                                         "initMesh",
#                                         "MC_Mesh_Domain",
#                                         "buildCells"
#                                     ],
#                                     "parent_hash#function": 1551109911967735083,
#                                     "depth#function": 5,
#                                     "retiring": 0.532664996,
#                                     "bad_speculation": 0.0050947829,
#                                     "frontend_bound": 0.1494873088,
#                                     "backend_bound": 0.3127529123,
#                                     "branch_mispredict": 0.8351774306,
#                                     "machine_clear": 0.1648225694,
#                                     "frontend_latency": 0.597949235,
#                                     "frontend_bandwidth": 0.402050765,
#                                     "memory_bound": 0.1158967468,
#                                     "core_bound": 0.2501339974,
#                                     "mem_bound": 0.0007938309,
#                                     "l1_bound": 0.1069167342,
#                                     "l2_bound": 0.0054101668,
#                                     "l3_bound": 0.0027760149,
#                                     "uncore_bound": 0.0035698458,
#                                     "boundedness": [
#                                         "retiring 53.27%"
#                                     ],
#                                     "children": [
#                                         {
#                                             "hash#function": -7264013457032837659,
#                                             "time.inclusive.duration": 469.0,
#                                             "cali.caliper.version": 1,
#                                             "function": [
#                                                 "main",
#                                                 "initMC",
#                                                 "initMesh",
#                                                 "MC_Mesh_Domain",
#                                                 "buildCells",
#                                                 "makeFacet"
#                                             ],
#                                             "parent_hash#function": -3346546285056646112,
#                                             "depth#function": 6,
#                                             "retiring": 0.5335692556,
#                                             "bad_speculation": 0.0044035749,
#                                             "frontend_bound": 0.148129659,
#                                             "backend_bound": 0.3138975105,
#                                             "branch_mispredict": 0.8186416042,
#                                             "machine_clear": 0.1813583958,
#                                             "frontend_latency": 0.592518636,
#                                             "frontend_bandwidth": 0.407481364,
#                                             "memory_bound": 0.1141731047,
#                                             "core_bound": 0.2499228214,
#                                             "mem_bound": 0.0007270711,
#                                             "l1_bound": 0.1062574274,
#                                             "l2_bound": 0.0055604088,
#                                             "l3_bound": 0.0016281974,
#                                             "uncore_bound": 0.0023552685,
#                                             "boundedness": [
#                                                 "retiring 53.36%"
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "hash#function": 8851638973338340585,
#                                     "time.inclusive.duration": 2096.0,
#                                     "cali.caliper.version": 1,
#                                     "function": [
#                                         "main",
#                                         "initMC",
#                                         "initMesh",
#                                         "MC_Mesh_Domain",
#                                         "bootstrapNodeMap"
#                                     ],
#                                     "parent_hash#function": 1551109911967735083,
#                                     "depth#function": 5,
#                                     "retiring": 0.3395788123,
#                                     "bad_speculation": 0.1463238139,
#                                     "frontend_bound": 0.0025632817,
#                                     "backend_bound": 0.5115340921,
#                                     "branch_mispredict": 1.0,
#                                     "machine_clear": 0.0,
#                                     "frontend_latency": 0.0102531266,
#                                     "frontend_bandwidth": 0.9897468734,
#                                     "memory_bound": 0.0429855707,
#                                     "core_bound": 0.3249230173,
#                                     "mem_bound": 0.0330557848,
#                                     "l1_bound": -0.0130192927,
#                                     "l2_bound": 0.0229490785,
#                                     "l3_bound": 0.0,
#                                     "uncore_bound": 0.0330557848,
#                                     "boundedness": [
#                                         "backend_bound 51.15%",
#                                         "core_bound 32.49%"
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "hash#function": 1635650414372769522,
#                             "time.inclusive.duration": 179145.0,
#                             "cali.caliper.version": 4,
#                             "function": [
#                                 "main",
#                                 "initMC",
# ...
#                                     "mem_bound": 0.0,
#                                     "l1_bound": -0.0041523437,
#                                     "l2_bound": 0.0041523437,
#                                     "l3_bound": 0.0,
#                                     "uncore_bound": 0.0,
#                                     "boundedness": [
#                                         "retiring 53.64%"
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "hash#function": 8375893045446190810,
#             "time.inclusive.duration": 3572462.0,
#             "cali.caliper.version": 3,
#             "function": [
#                 "main",
#                 "cycleTracking"
#             ],
#             "parent_hash#function": 1128851083484916900,
#             "depth#function": 2,
#             "retiring": 0.4684239371,
#             "bad_speculation": 0.0232663576,
#             "frontend_bound": 0.0692260657,
#             "backend_bound": 0.4390836396,
#             "branch_mispredict": 0.9895379861,
#             "machine_clear": 0.0104620139,
#             "frontend_latency": 0.276904263,
#             "frontend_bandwidth": 0.723095737,
#             "memory_bound": 0.1854429512,
#             "core_bound": 0.2471592723,
#             "mem_bound": 0.0001539389,
#             "l1_bound": 0.1515197379,
#             "l2_bound": 0.0036714773,
#             "l3_bound": 0.0300977972,
#             "uncore_bound": 0.0302517361,
#             "boundedness": [
#                 "retiring 46.84%"
#             ],
#             "children": [
#                 {
#                     "hash#function": 3152381168709113512,
#                     "time.inclusive.duration": 78.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "cycleTracking",
#                         "SumTasks"
#                     ],
#                     "parent_hash#function": 8375893045446190810,
#                     "depth#function": 3,
#                     "retiring": 0.4778011877,
#                     "bad_speculation": 0.0133067155,
#                     "frontend_bound": 0.1431423574,
#                     "backend_bound": 0.3657497395,
#                     "branch_mispredict": 0.8919841796,
#                     "machine_clear": 0.1080158204,
#                     "frontend_latency": 0.5725694296,
#                     "frontend_bandwidth": 0.4274305704,
#                     "memory_bound": 0.1797069006,
#                     "core_bound": 0.2576678334,
#                     "mem_bound": 0.0001151872,
#                     "l1_bound": 0.1176568311,
#                     "l2_bound": 0.0152242858,
#                     "l3_bound": 0.0467105965,
#                     "uncore_bound": 0.0468257837,
#                     "boundedness": [
#                         "retiring 47.78%"
#                     ]
#                 },
#                 {
#                     "hash#function": 5561175753082870147,
#                     "time.inclusive.duration": 379.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "cycleTracking",
#                         "collapse"
#                     ],
#                     "parent_hash#function": 8375893045446190810,
#                     "depth#function": 3,
#                     "retiring": 0.3461024054,
#                     "bad_speculation": 0.0047153546,
#                     "frontend_bound": 0.094345218,
#                     "backend_bound": 0.554837022,
#                     "branch_mispredict": 0.9046602625,
#                     "machine_clear": 0.0953397375,
#                     "frontend_latency": 0.3773808718,
#                     "frontend_bandwidth": 0.6226191282,
#                     "memory_bound": 0.233320004,
#                     "core_bound": 0.2980737048,
#                     "mem_bound": 0.0009392286,
#                     "l1_bound": 0.1302552635,
#                     "l2_bound": 0.0210114605,
#                     "l3_bound": 0.0811140514,
#                     "uncore_bound": 0.08205328,
#                     "boundedness": [
#                         "backend_bound 55.48%",
#                         "core_bound 29.81%"
#                     ]
#                 }
#             ]
#         },
#         {
#             "hash#function": 9031087567878469606,
#             "time.inclusive.duration": 128275.0,
#             "cali.caliper.version": 5,
#             "function": [
#                 "main",
#                 "cycleInit"
#             ],
#             "parent_hash#function": 1128851083484916900,
#             "depth#function": 2,
#             "retiring": 0.5345237257,
#             "bad_speculation": 0.0152513617,
#             "frontend_bound": 0.0888626384,
#             "backend_bound": 0.3613622743,
#             "branch_mispredict": 0.9569640842,
#             "machine_clear": 0.0430359158,
#             "frontend_latency": 0.3554505536,
#             "frontend_bandwidth": 0.6445494464,
#             "memory_bound": 0.1685448979,
#             "core_bound": 0.2518570104,
#             "mem_bound": 0.0002227598,
#             "l1_bound": 0.1617561285,
#             "l2_bound": 0.0010182541,
#             "l3_bound": 0.0055477555,
#             "uncore_bound": 0.0057705153,
#             "boundedness": [
#                 "retiring 53.45%"
#             ],
#             "children": [
#                 {
#                     "hash#function": -8529677498755232928,
#                     "time.inclusive.duration": 1574.0,
#                     "cali.caliper.version": 2,
#                     "function": [
#                         "main",
#                         "cycleInit",
#                         "RouletteLowWeightParticles"
#                     ],
#                     "parent_hash#function": 9031087567878469606,
#                     "depth#function": 3,
#                     "retiring": 0.4791208206,
#                     "bad_speculation": 0.0851812389,
#                     "frontend_bound": 0.7227838323,
#                     "backend_bound": -0.2870858917,
#                     "branch_mispredict": 0.9458852701,
#                     "machine_clear": 0.0541147299,
#                     "frontend_latency": 2.8911353291,
#                     "frontend_bandwidth": -1.8911353291,
#                     "memory_bound": 0.3113286889,
#                     "core_bound": 0.2500912036,
#                     "mem_bound": 9.98035e-05,
#                     "l1_bound": 0.2741180783,
#                     "l2_bound": 0.008010774,
#                     "l3_bound": 0.0291000331,
#                     "uncore_bound": 0.0291998366,
#                     "boundedness": [
#                         "frontend_bound 72.28%",
#                         "frontend_latency 289.11%"
#                     ],
#                     "children": [
#                         {
#                             "hash#function": 8060419455817356433,
#                             "time.inclusive.duration": 91.0,
#                             "cali.caliper.version": 1,
#                             "function": [
#                                 "main",
#                                 "cycleInit",
#                                 "RouletteLowWeightParticles",
#                                 "collapse"
#                             ],
#                             "parent_hash#function": -8529677498755232928,
#                             "depth#function": 4,
#                             "retiring": 0.4681836648,
#                             "bad_speculation": 0.0181982189,
#                             "frontend_bound": 0.1505766301,
#                             "backend_bound": 0.3630414862,
#                             "branch_mispredict": 0.8210499095,
#                             "machine_clear": 0.1789500905,
#                             "frontend_latency": 0.6023065204,
#                             "frontend_bandwidth": 0.3976934796,
#                             "memory_bound": 0.2625070997,
#                             "core_bound": 0.0549571464,
#                             "mem_bound": 0.0006930714,
#                             "l1_bound": 0.1783630798,
#                             "l2_bound": 0.0172081741,
#                             "l3_bound": 0.0662427744,
#                             "uncore_bound": 0.0669358458,
#                             "boundedness": [
#                                 "retiring 46.82%"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "hash#function": -6369133219933570523,
#                     "time.inclusive.duration": 2945.0,
#                     "cali.caliper.version": 2,
#                     "function": [
#                         "main",
#                         "cycleInit",
#                         "PopulationControl"
#                     ],
#                     "parent_hash#function": 9031087567878469606,
#                     "depth#function": 3,
#                     "retiring": 0.3551411167,
#                     "bad_speculation": 0.0452955925,
#                     "frontend_bound": 0.110011306,
#                     "backend_bound": 0.4895519848,
#                     "branch_mispredict": 0.7838182268,
#                     "machine_clear": 0.2161817732,
#                     "frontend_latency": 0.4400452241,
#                     "frontend_bandwidth": 0.5599547759,
#                     "memory_bound": 0.1808650274,
#                     "core_bound": 0.3287101494,
#                     "mem_bound": 0.0019865626,
#                     "l1_bound": 0.1652351812,
#                     "l2_bound": -0.0002031711,
#                     "l3_bound": 0.0138464547,
#                     "uncore_bound": 0.0158330173,
#                     "boundedness": [
#                         "backend_bound 48.96%",
#                         "core_bound 32.87%"
#                     ],
#                     "children": [
#                         {
#                             "hash#function": -1577712999096161133,
#                             "time.inclusive.duration": 2716.0,
#                             "cali.caliper.version": 1,
#                             "function": [
#                                 "main",
#                                 "cycleInit",
#                                 "PopulationControl",
#                                 "PopulationControlGuts"
#                             ],
#                             "parent_hash#function": -6369133219933570523,
#                             "depth#function": 4,
#                             "retiring": 0.3578652428,
#                             "bad_speculation": 0.0457407245,
#                             "frontend_bound": 0.1105077115,
#                             "backend_bound": 0.4858863212,
#                             "branch_mispredict": 0.7781820575,
#                             "machine_clear": 0.2218179425,
#                             "frontend_latency": 0.442030846,
#                             "frontend_bandwidth": 0.557969154,
#                             "memory_bound": 0.1788315226,
#                             "core_bound": 0.3398921995,
#                             "mem_bound": 0.0020898337,
#                             "l1_bound": 0.1675796353,
#                             "l2_bound": -0.0006982187,
#                             "l3_bound": 0.0098602723,
#                             "uncore_bound": 0.011950106,
#                             "boundedness": [
#                                 "backend_bound 48.59%",
#                                 "core_bound 33.99%"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "hash#function": -788602314893872686,
#                     "time.inclusive.duration": 61.0,
#                     "cali.caliper.version": 1,
#                     "function": [
#                         "main",
#                         "cycleInit",
#                         "CycleInitialize"
#                     ],
#                     "parent_hash#function": 9031087567878469606,
#                     "depth#function": 3,
#                     "retiring": 0.5631714774,
#                     "bad_speculation": -0.057508431,
#                     "frontend_bound": 0.124998818,
#                     "backend_bound": 0.3693381356,
#                     "branch_mispredict": 0.9130434783,
#                     "machine_clear": 0.0869565217,
#                     "frontend_latency": 0.4999952718,
#                     "frontend_bandwidth": 0.5000047282,
#                     "memory_bound": 0.2249420501,
#                     "core_bound": 0.2628751674,
#                     "mem_bound": 0.0,
#                     "l1_bound": 0.1698881428,
#                     "l2_bound": 0.011317523,
#                     "l3_bound": 0.0437363843,
#                     "uncore_bound": 0.0437363843,
#                     "boundedness": [
#                         "retiring 56.32%"
#                     ]
#                 },
#                 {
#                     "hash#function": 6392707864436864065,
#                     "time.inclusive.duration": 348.0,
#                     "cali.caliper.version": 2,
#                     "function": [
#                         "main",
#                         "cycleInit",
#                         "clearCrossSectionCache"
#                     ],
#                     "parent_hash#function": 9031087567878469606,
#                     "depth#function": 3,
#                     "retiring": 0.7116173254,
#                     "bad_speculation": 0.0187630206,
#                     "frontend_bound": 0.0993370633,
#                     "backend_bound": 0.1702825907,
#                     "branch_mispredict": 0.9487222385,
#                     "machine_clear": 0.0512777615,
#                     "frontend_latency": 0.3973482531,
#                     "frontend_bandwidth": 0.6026517469,
#                     "memory_bound": 0.0847819143,
#                     "core_bound": 0.1496635014,
#                     "mem_bound": 3.00289e-05,
#                     "l1_bound": 0.0511975396,
#                     "l2_bound": 0.0020926901,
#                     "l3_bound": 0.0314616558,
#                     "uncore_bound": 0.0314916846,
#                     "boundedness": [
#                         "retiring 71.16%"
#                     ],
#                     "children": [
#                         {
#                             "hash#function": -9027588662820252036,
#                             "time.inclusive.duration": 310.0,
#                             "cali.caliper.version": 1,
#                             "function": [
#                                 "main",
#                                 "cycleInit",
#                                 "clearCrossSectionCache",
#                                 "clearCrossSectionCache"
#                             ],
#                             "parent_hash#function": 6392707864436864065,
#                             "depth#function": 4,
#                             "retiring": 0.7485655599,
#                             "bad_speculation": 0.0204619804,
#                             "frontend_bound": 0.0978350884,
#                             "backend_bound": 0.1331373713,
#                             "branch_mispredict": 0.9499061422,
#                             "machine_clear": 0.0500938578,
#                             "frontend_latency": 0.3913403537,
#                             "frontend_bandwidth": 0.6086596463,
#                             "memory_bound": 0.0594110256,
#                             "core_bound": 0.1395866545,
#                             "mem_bound": 0.0,
#                             "l1_bound": 0.0381382994,
#                             "l2_bound": 0.0006779063,
#                             "l3_bound": 0.0205948199,
#                             "uncore_bound": 0.0205948199,
#                             "boundedness": [
#                                 "retiring 74.86%"
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }

# %%
tree.hot_path('time.inclusive.duration')
# Out:
#           hash#function  time.inclusive.duration  cali.caliper.version  \
# 0   1128851083484916900               37213720.0                    15
# 13  8375893045446190810                3572462.0                     3
# 38  5561175753082870147                    379.0                     1
#
#                            function  parent_hash#function  depth#function  \
# 0                           (main,)               3527539               1
# 13            (main, cycleTracking)   1128851083484916900               2
# 38  (main, cycleTracking, collapse)   8375893045446190810               3
#
#     retiring  bad_speculation  frontend_bound  backend_bound  \
# 0   0.488457         0.017789        0.098757       0.394996
# 13  0.468424         0.023266        0.069226       0.439084
# 38  0.346102         0.004715        0.094345       0.554837
#
#                       ...                      frontend_latency  \
# 0                     ...                              0.395029
# 13                    ...                              0.276904
# 38                    ...                              0.377381
#
#     frontend_bandwidth  memory_bound  core_bound  mem_bound  l1_bound  \
# 0             0.604971      0.163454    0.250706   0.000440  0.137907
# 13            0.723096      0.185443    0.247159   0.000154  0.151520
# 38            0.622619      0.233320    0.298074   0.000939  0.130255
#
#     l2_bound  l3_bound  uncore_bound  \
# 0   0.003898  0.021210      0.021649
# 13  0.003671  0.030098      0.030252
# 38  0.021011  0.081114      0.082053
#
#                                   boundedness
# 0                           [retiring 48.85%]
# 13                          [retiring 46.84%]
# 38  [backend_bound 55.48%, core_bound 29.81%]
#
# [3 rows x 22 columns]

# %%
import util
import json

print(util.pretty_json_dumps(json.loads(tree.hot_path('time.inclusive.duration').to_json(orient='records'))))
# Out:
# [
#     {
#         "hash#function": 1128851083484916900,
#         "time.inclusive.duration": 37213720.0,
#         "cali.caliper.version": 15,
#         "function": [
#             "main"
#         ],
#         "parent_hash#function": 3527539,
#         "depth#function": 1,
#         "retiring": 0.4884572575,
#         "bad_speculation": 0.0177889881,
#         "frontend_bound": 0.0987573261,
#         "backend_bound": 0.3949964282,
#         "branch_mispredict": 0.9716684103,
#         "machine_clear": 0.0283315897,
#         "frontend_latency": 0.3950293045,
#         "frontend_bandwidth": 0.6049706955,
#         "memory_bound": 0.1634543727,
#         "core_bound": 0.2507063494,
#         "mem_bound": 0.0004396511,
#         "l1_bound": 0.1379074174,
#         "l2_bound": 0.0038977746,
#         "l3_bound": 0.0212095295,
#         "uncore_bound": 0.0216491806,
#         "boundedness": [
#             "retiring 48.85%"
#         ]
#     },
#     {
#         "hash#function": 8375893045446190810,
#         "time.inclusive.duration": 3572462.0,
#         "cali.caliper.version": 3,
#         "function": [
#             "main",
#             "cycleTracking"
#         ],
#         "parent_hash#function": 1128851083484916900,
#         "depth#function": 2,
#         "retiring": 0.4684239371,
#         "bad_speculation": 0.0232663576,
#         "frontend_bound": 0.0692260657,
#         "backend_bound": 0.4390836396,
#         "branch_mispredict": 0.9895379861,
#         "machine_clear": 0.0104620139,
#         "frontend_latency": 0.276904263,
#         "frontend_bandwidth": 0.723095737,
#         "memory_bound": 0.1854429512,
#         "core_bound": 0.2471592723,
#         "mem_bound": 0.0001539389,
#         "l1_bound": 0.1515197379,
#         "l2_bound": 0.0036714773,
#         "l3_bound": 0.0300977972,
#         "uncore_bound": 0.0302517361,
#         "boundedness": [
#             "retiring 46.84%"
#         ]
#     },
#     {
#         "hash#function": 5561175753082870147,
#         "time.inclusive.duration": 379.0,
#         "cali.caliper.version": 1,
#         "function": [
#             "main",
#             "cycleTracking",
#             "collapse"
#         ],
#         "parent_hash#function": 8375893045446190810,
#         "depth#function": 3,
#         "retiring": 0.3461024054,
#         "bad_speculation": 0.0047153546,
#         "frontend_bound": 0.094345218,
#         "backend_bound": 0.554837022,
#         "branch_mispredict": 0.9046602625,
#         "machine_clear": 0.0953397375,
#         "frontend_latency": 0.3773808718,
#         "frontend_bandwidth": 0.6226191282,
#         "memory_bound": 0.233320004,
#         "core_bound": 0.2980737048,
#         "mem_bound": 0.0009392286,
#         "l1_bound": 0.1302552635,
#         "l2_bound": 0.0210114605,
#         "l3_bound": 0.0811140514,
#         "uncore_bound": 0.08205328,
#         "boundedness": [
#             "backend_bound 55.48%",
#             "core_bound 29.81%"
#         ]
#     }
# ]
