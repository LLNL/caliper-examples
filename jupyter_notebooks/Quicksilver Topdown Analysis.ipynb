# %%
import pandas as pd

pd.set_option("display.max_columns",0)
pd.set_option("display.max_colwidth",0)

# %% [markdown]
# # Load Caliper JSON Data
# Drop data with empty function annotations and split function nestings into tuples "main/foo/bar" -> (main, foo, bar)

# %%
# Large files (>1gb) should be read in 1000 lines at a time and concatenated together, like so:
df = pd.concat(
    pd.read_json('../datasets/quicksilver_topdown_counters.json', orient='records', lines=True, chunksize=1000)
)
df = df.dropna(subset=['function'])
df['function'] = df['function'].transform(lambda l: tuple(l.split('/')))
df.head()
# Out:
#     cali.caliper.version  cali.event.begin     ...       time.inclusive.duration  time.offset
# 114  1.7.0-dev            334.0                ...      NaN                       2813734
# 115  1.7.0-dev           NaN                   ...       17.0                     32336221
# 117  1.7.0-dev            334.0                ...      NaN                       29924061
# 119  1.7.0-dev            334.0                ...      NaN                       32380275
# 120  1.7.0-dev           NaN                   ...       21.0                     2813755
#
# [5 rows x 31 columns]

# %% [markdown]
# # Perform Inclusive Aggregation (Derive the "Call Tree")

# %%
from cali_analysis import hatchet

# %% [markdown]
# ## Define per-column aggregators

# %%
aggregators = dict([ (c, 'sum') for c in filter(lambda col: 'libpfm' in col, df.columns)])
aggregators['time.inclusive.duration'] = 'max'
aggregators['cali.caliper.version'] = 'count'
aggregators
# Out:
# {'cali.caliper.version': 'count',
#  'libpfm.counter.BR_MISP_RETIRED:ALL_BRANCHES': 'sum',
#  'libpfm.counter.CPU_CLK_UNHALTED:THREAD_P': 'sum',
#  'libpfm.counter.CYCLE_ACTIVITY:CYCLES_NO_EXECUTE': 'sum',
#  'libpfm.counter.CYCLE_ACTIVITY:STALLS_L1D_PENDING': 'sum',
#  'libpfm.counter.CYCLE_ACTIVITY:STALLS_L2_PENDING': 'sum',
#  'libpfm.counter.CYCLE_ACTIVITY:STALLS_LDM_PENDING': 'sum',
#  'libpfm.counter.IDQ:MS_UOPS': 'sum',
#  'libpfm.counter.IDQ_UOPS_NOT_DELIVERED:CORE': 'sum',
#  'libpfm.counter.INT_MISC:RECOVERY_CYCLES': 'sum',
#  'libpfm.counter.MACHINE_CLEARS:COUNT': 'sum',
#  'libpfm.counter.MEM_LOAD_UOPS_RETIRED:L3_HIT': 'sum',
#  'libpfm.counter.MEM_LOAD_UOPS_RETIRED:L3_MISS': 'sum',
#  'libpfm.counter.RESOURCE_STALLS:SB': 'sum',
#  'libpfm.counter.RS_EVENTS:EMPTY_CYCLES': 'sum',
#  'libpfm.counter.UOPS_EXECUTED:CORE_CYCLES_GE_1': 'sum',
#  'libpfm.counter.UOPS_EXECUTED:CORE_CYCLES_GE_2': 'sum',
#  'libpfm.counter.UOPS_EXECUTED:THREAD': 'sum',
#  'libpfm.counter.UOPS_ISSUED:ANY': 'sum',
#  'libpfm.counter.UOPS_RETIRED:RETIRE_SLOTS': 'sum',
#  'time.inclusive.duration': 'max'}

# %% [markdown]
# ## Create multi-rooted tree from the samples, using our aggregators

# %%
mrt = hatchet.MultiRootTree.from_samples(df, 'function', aggregators)
mrt.df_nodes[['function', 'time.inclusive.duration', 'libpfm.counter.UOPS_EXECUTED:THREAD']].head()
# Out:
#                                                                                                                            function  time.inclusive.duration  libpfm.counter.UOPS_EXECUTED:THREAD
# 50  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, addTupleToQueue, tupleToIndex)  79.0                     2215438952
# 14  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2, indexToTuple)                         48.0                     2035192437
# 21  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addTupleToQueue, tupleToIndex)                  148.0                    682603152
# 26  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2, whichCellTuple)                       99.0                     2043227374
# 52  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, addTupleToQueue)                171.0                    6646474530

# %% [markdown]
# # Derive Topdown Analysis metrics
# Calculates the topdown derived metrics as described in http://ieeexplore.ieee.org/document/6844459/

# %%
from cali_analysis import topdown

# %%
df_td = topdown.derive_topdown_ivb(mrt.df_nodes)
df_td.head()
# Out:
#           hash#function  time.inclusive.duration     ...       l3_bound uncore_bound
# 50 -647878498448900250   79.0                        ...       0.002175  0.002272
# 14 -6803774206164476110  48.0                        ...       0.002439  0.002516
# 21 -5098735054641025010  148.0                       ...       0.002258  0.002334
# 26 -3897821748422853644  99.0                        ...       0.002548  0.002604
# 52  28494405572918431    171.0                       ...       0.002261  0.002356
#
# [5 rows x 21 columns]

# %% [markdown]
# # Determine Topdown boundedness
# Using derived metrics, determines which function paths are bound by which resources

# %%
pd.set_option("display.max_rows",999)

dfb = topdown.analyze_topdown_metrics(df_td)
sorted_dfb = dfb.sort_values(['depth#function', 'time.inclusive.duration'], ascending=[True, False])
sorted_dfb[['function','time.inclusive.duration', 'boundedness', 'memory_bound', 'l1_bound', 'l2_bound', 'l3_bound']].dropna()
# Out:
#                                                                                                                            function  time.inclusive.duration                                                       boundedness  memory_bound  l1_bound  l2_bound  l3_bound
# 0   (main,)                                                                                                                          37213720.0               [retiring 48.85%]                                                 0.163454      0.137907  0.003898  0.021210
# 10  (main, cycleTracking)                                                                                                            3572462.0                [retiring 46.84%]                                                 0.185443      0.151520  0.003671  0.030098
# 13  (main, initMC)                                                                                                                   2829809.0                [retiring 53.37%]                                                 0.118970      0.110911  0.004571  0.002979
# 9   (main, cycleInit)                                                                                                                128275.0                 [retiring 53.45%]                                                 0.168545      0.161756  0.001018  0.005548
# 1   (main, parseInputFile)                                                                                                           17550.0                  [retiring 61.06%]                                                 0.149088      0.141534 -0.000045  0.006747
# 7   (main, cycleFinalize)                                                                                                            2597.0                   [backend_bound 51.33%, memory_bound 7.32%, l1_bound 5.44%]        0.073193      0.054443  0.003145  0.015419
# 12  (main, freeArgs)                                                                                                                 1045.0                   [backend_bound 71.21%, memory_bound 16.85%, l1_bound 15.60%]      0.168471      0.156003  0.006754  0.005714
# 11  (main, gameOver)                                                                                                                 623.0                    [backend_bound 49.21%, memory_bound 62.30%, uncore_bound 44.30%]  0.622959      0.314746 -0.134761  0.174897
# 5   (main, ~MonteCarlo)                                                                                                              618.0                    [backend_bound 61.74%, memory_bound 128.95%, l1_bound 68.60%]     1.289460      0.686002  0.071766  0.127417
# 8   (main, coralBenchmarkCorrectness)                                                                                                598.0                    [backend_bound 65.56%, memory_bound 35.20%, l1_bound 33.02%]      0.351969      0.330192  0.001093  0.015224
# 14  (main, processArgs)                                                                                                              503.0                    [backend_bound 63.84%, core_bound 21.40%]                         0.142262      0.108707  0.009489  0.022993
# 0   (main, printParameters)                                                                                                          341.0                    [backend_bound 64.59%, memory_bound 77.02%, l1_bound 47.78%]      0.770185      0.477757  0.025426  0.267001
# 6   (main, addArg)                                                                                                                   202.0                    [backend_bound 55.32%, memory_bound 10.58%, l1_bound 9.61%]       0.105794      0.096108  0.004712  0.004973
# 4   (main, supplyDefaults)                                                                                                           43.0                     [backend_bound 65.27%, memory_bound 15.53%, l1_bound 14.70%]      0.155319      0.146966  0.005793  0.002560
# 0   (main, initMC, initMesh)                                                                                                         2816012.0                [retiring 53.42%]                                                 0.118115      0.110172  0.004601  0.002942
# 5   (main, initMC, MonteCarlo)                                                                                                       10000.0                  [backend_bound 65.85%, memory_bound 71.88%, l1_bound 65.01%]      0.718801      0.650150 -0.017045  0.011030
# 36  (main, parseInputFile, readBlock)                                                                                                3986.0                   [retiring 62.73%]                                                 0.000000     -0.003930  0.003016  0.000909
# 22  (main, initMC, initNuclearData)                                                                                                  3690.0                   [retiring 95.38%]                                                 0.006514      0.000988  0.003277  0.001045
# 9   (main, cycleInit, PopulationControl)                                                                                             2945.0                   [backend_bound 48.96%, core_bound 32.87%]                         0.180865      0.165235 -0.000203  0.013846
# 1   (main, cycleFinalize, CycleFinalize)                                                                                             2553.0                   [backend_bound 51.40%, memory_bound 7.07%, l1_bound 5.36%]        0.070712      0.053645  0.002903  0.013981
# 14  (main, cycleInit, RouletteLowWeightParticles)                                                                                    1574.0                   [frontend_bound 72.28%, frontend_latency 289.11%]                 0.311329      0.274118  0.008011  0.029100
# 17  (main, initMC, initTallies)                                                                                                      1377.0                   [backend_bound 81.63%, core_bound 83.99%]                         0.246026      0.184536  0.011602  0.016586
# 45  (main, gameOver, Cumulative_Report)                                                                                              588.0                    [backend_bound 48.12%, memory_bound 64.59%, uncore_bound 48.79%]  0.645916      0.312159 -0.154107  0.184342
# 29  (main, coralBenchmarkCorrectness, FluenceTest)                                                                                   563.0                    [backend_bound 66.34%, memory_bound 34.74%, l1_bound 33.40%]      0.347404      0.334006  0.000611  0.012087
# 28  (main, cycleTracking, collapse)                                                                                                  379.0                    [backend_bound 55.48%, core_bound 29.81%]                         0.233320      0.130255  0.021011  0.081114
# 2   (main, cycleInit, clearCrossSectionCache)                                                                                        348.0                    [retiring 71.16%]                                                 0.084782      0.051198  0.002093  0.031462
# 20  (main, parseInputFile, blockStart)                                                                                               320.0                    [retiring 53.10%]                                                 0.021672      0.015787  0.005885  0.000000
# 13  (main, addArg, myOptionAlloc)                                                                                                    134.0                    [backend_bound 54.96%, memory_bound 10.55%, l1_bound 9.52%]       0.105465      0.095185  0.004489  0.005791
# 26  (main, cycleTracking, SumTasks)                                                                                                  78.0                     [retiring 47.78%]                                                 0.179707      0.117657  0.015224  0.046711
# 42  (main, addArg, lastOption)                                                                                                       63.0                     [backend_bound 55.43%, memory_bound 11.05%, l1_bound 10.13%]      0.110456      0.101310  0.005784  0.003363
# 21  (main, cycleInit, CycleInitialize)                                                                                               61.0                     [retiring 56.32%]                                                 0.224942      0.169888  0.011318  0.043736
# 25  (main, processArgs, findOption)                                                                                                  51.0                     [backend_bound 66.23%, core_bound 20.18%]                         0.129717      0.114487  0.008141  0.007089
# 24  (main, freeArgs, myOptionFree)                                                                                                   49.0                     [backend_bound 71.33%, memory_bound 16.83%, l1_bound 15.51%]      0.168287      0.155076  0.006994  0.006216
# 30  (main, parseInputFile, scanMaterialBlock)                                                                                        37.0                     [backend_bound 59.30%, memory_bound 17.03%, l1_bound 11.84%]      0.170282      0.118372  0.011540  0.040369
# 40  (main, parseInputFile, scanCrossSectionBlock)                                                                                    36.0                     [backend_bound 62.09%, memory_bound 16.38%, l1_bound 12.45%]      0.163783      0.124476  0.011314  0.027993
# 10  (main, parseInputFile, InputBlock)                                                                                               33.0                     [backend_bound 69.83%, memory_bound 12.40%, l1_bound 10.01%]      0.124045      0.100093 -0.005962  0.029914
# 15  (main, parseInputFile, scanGeometryBlock)                                                                                        30.0                     [backend_bound 62.05%, memory_bound 17.34%, l1_bound 11.37%]      0.173379      0.113692  0.014911  0.044775
# 23  (main, parseInputFile, deserialize)                                                                                              28.0                     [backend_bound 65.72%, memory_bound 12.39%, l1_bound 10.93%]      0.123933      0.109297 -0.000600  0.015237
# 6   (main, initMC, initTimeInfo)                                                                                                     22.0                     [retiring 159.68%]                                                0.000000      0.000000  0.000000  0.000000
# 4   (main, initMC, initGPUInfo)                                                                                                      19.0                     [retiring 131.24%]                                                0.000000      0.000000  0.000000  0.000000
# 38  (main, initMC, checkCrossSections)                                                                                               19.0                     [backend_bound 45.03%, core_bound 48.72%]                         0.192036      0.099128  0.031536  0.058117
# 7   (main, initMC, initMesh, buildMeshPartition)                                                                                     1578416.0                [retiring 53.67%]                                                 0.119964      0.113074  0.003966  0.002829
# 30  (main, initMC, initMesh, MC_Mesh_Domain)                                                                                         1058573.0                [retiring 53.03%]                                                 0.115861      0.106456  0.005521  0.003023
# 65  (main, initMC, initMesh, MC_Domain)                                                                                              179145.0                 [retiring 53.52%]                                                 0.114508      0.105815  0.004903  0.003538
# 63  (main, cycleInit, PopulationControl, PopulationControlGuts)                                                                      2716.0                   [backend_bound 48.59%, core_bound 33.99%]                         0.178832      0.167580 -0.000698  0.009860
# 33  (main, initMC, initTallies, InitializeTallies)                                                                                   1325.0                   [backend_bound 82.23%, core_bound 85.40%]                         0.248061      0.189065  0.010859  0.015093
# 42  (main, cycleFinalize, CycleFinalize, PrintSummary)                                                                               1258.0                   [backend_bound 55.66%, core_bound 4.11%]                          0.038029      0.019415  0.003824  0.014559
# 69  (main, cycleFinalize, CycleFinalize, compute)                                                                                    983.0                    [backend_bound 55.32%, memory_bound 10.75%, l1_bound 10.14%]      0.107505      0.101430  0.000335  0.005667
# 64  (main, initMC, initNuclearData, addIsotope)                                                                                      385.0                    [retiring 95.27%]                                                 0.006423      0.000797  0.003312  0.001278
# 9   (main, cycleInit, clearCrossSectionCache, clearCrossSectionCache)                                                                310.0                    [retiring 74.86%]                                                 0.059411      0.038138  0.000678  0.020595
# 8   (main, parseInputFile, blockStart, split)                                                                                        224.0                    [retiring 53.64%]                                                 0.009249      0.005280  0.003969  0.000000
# 14  (main, parseInputFile, readBlock, split)                                                                                         168.0                    [retiring 62.93%]                                                 0.000000     -0.003304  0.002673  0.000625
# 6   (main, cycleInit, RouletteLowWeightParticles, collapse)                                                                          91.0                     [retiring 46.82%]                                                 0.262507      0.178363  0.017208  0.066243
# 51  (main, initMC, initMesh, getBoundaryCondition)                                                                                   67.0                     [retiring 58.23%]                                                 0.054174      0.001437  0.026651  0.000000
# 32  (main, addArg, myOptionAlloc, dupString)                                                                                         51.0                     [backend_bound 54.71%, memory_bound 10.63%, l1_bound 9.59%]       0.106267      0.095855  0.004121  0.006291
# 46  (main, initMC, initNuclearData, NuclearData)                                                                                     46.0                     [retiring 90.40%]                                                 0.000000      0.000000  0.000000  0.000000
# 39  (main, parseInputFile, readBlock, isComment)                                                                                     39.0                     [retiring 62.46%]                                                 0.000000     -0.003260  0.002376  0.000884
# 11  (main, parseInputFile, readBlock, addPair)                                                                                       35.0                     [retiring 64.95%]                                                 0.000000     -0.003492  0.002840  0.000652
# 3   (main, initMC, initMesh, initializeCentersGrid)                                                                                  28.0                     [retiring 47.76%]                                                 0.027416      0.016320  0.006590  0.001453
# 52  (main, gameOver, Cumulative_Report, Print_Cumulative_Heading)                                                                    27.0                     [backend_bound 54.29%, memory_bound 55.00%, l1_bound 30.50%]      0.550033      0.304967 -0.044648  0.265513
# 59  (main, cycleFinalize, CycleFinalize, SumTasks)                                                                                   25.0                     [backend_bound 48.20%, core_bound 37.68%]                         0.118122      0.065142  0.020372  0.031700
# 22  (main, initMC, initMesh, DecompositionObject)                                                                                    23.0                     [retiring 46.97%]                                                 0.024344      0.017444  0.005354  0.001546
# 0   (main, initMC, initMesh, MeshPartition)                                                                                          19.0                     [retiring 52.52%]                                                 0.024543      0.019628  0.003163  0.001752
# 61  (main, initMC, initMesh, MpiCommObject)                                                                                          19.0                     [retiring 51.42%]                                                 0.025100      0.017895  0.004842  0.002363
# 55  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain)                                                                1576489.0                [retiring 53.30%]                                                 0.113434      0.105704  0.004479  0.003156
# 51  (main, initMC, initMesh, MC_Mesh_Domain, buildCells)                                                                             1053554.0                [retiring 53.27%]                                                 0.115897      0.106917  0.005410  0.002776
# 56  (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap)                                                                  346187.0                 [retiring 56.47%]                                                 0.170806      0.170467 -0.000024  0.000255
# 66  (main, initMC, initMesh, MC_Mesh_Domain, bootstrapNodeMap)                                                                       2096.0                   [backend_bound 51.15%, core_bound 32.49%]                         0.042986     -0.013019  0.022949  0.000000
# 12  (main, cycleFinalize, CycleFinalize, PrintSummary, ScalarFluxSum)                                                                1090.0                   [backend_bound 56.43%, memory_bound 1.83%, l1_bound 0.96%]        0.018304      0.009552  0.001213  0.007432
# 30  (main, initMC, initMesh, MC_Domain, findMaterial)                                                                                178.0                    [retiring 53.99%]                                                 0.111752      0.104820  0.004550  0.002293
# 32  (main, initMC, initMesh, MC_Domain, findCellCenter)                                                                              158.0                    [retiring 53.48%]                                                 0.115223      0.105973  0.005041  0.004081
# 77  (main, initMC, initNuclearData, addIsotope, addReaction)                                                                         127.0                    [retiring 94.15%]                                                 0.006743      0.000532  0.003488  0.001409
# 68  (main, parseInputFile, blockStart, split, chop)                                                                                  62.0                     [retiring 53.64%]                                                 0.000000     -0.004152  0.004152  0.000000
# 42  (main, initMC, initMesh, MC_Domain, cellVolume)                                                                                  55.0                     [retiring 53.87%]                                                 0.112476      0.103777  0.005177  0.003426
# 33  (main, parseInputFile, readBlock, split, chop)                                                                                   49.0                     [retiring 61.39%]                                                 0.000000     -0.003099  0.002710  0.000375
# 6   (main, parseInputFile, blockStart, split, validKeyword)                                                                          38.0                     [retiring 54.00%]                                                 0.000000     -0.001940  0.001940  0.000000
# 25  (main, cycleFinalize, CycleFinalize, PrintSummary, Print0)                                                                       38.0                     [backend_bound 49.63%, core_bound 30.80%]                         0.154532      0.087242  0.020901  0.043827
# 4   (main, parseInputFile, readBlock, split, validKeyword)                                                                           35.0                     [retiring 64.16%]                                                 0.000000     -0.001674  0.001408  0.000265
# 22  (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap, exchange)                                                        345831.0                 [retiring 56.49%]                                                 0.170392      0.170162 -0.000005  0.000128
# 42  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter)                                                 1082.0                   [retiring 53.44%]                                                 0.112503      0.105585  0.004315  0.002519
# 89  (main, initMC, initMesh, MC_Mesh_Domain, buildCells, makeFacet)                                                                  469.0                    [retiring 53.36%]                                                 0.114173      0.106257  0.005560  0.001628
# 72  (main, initMC, initMesh, MC_Domain, findMaterial, isInside)                                                                      124.0                    [retiring 54.03%]                                                 0.111133      0.104414  0.004462  0.002165
# 27  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell)                                                     123.0                    [retiring 63.11%]                                                 0.024614      0.018163  0.005339  0.000845
# 53  (main, initMC, initNuclearData, addIsotope, addReaction, NuclearDataReaction)                                                    77.0                     [retiring 91.68%]                                                 0.007298      0.001754  0.003183  0.000958
# 40  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, addNbrsToFlood)                                                51.0                     [retiring 47.69%]                                                 0.153730      0.117296  0.010495  0.025643
# 82  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue)                                 329.0                    [retiring 53.62%]                                                 0.112162      0.105559  0.004214  0.002297
# 98  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2)                                       213.0                    [retiring 53.44%]                                                 0.112364      0.105537  0.004298  0.002456
# 2   (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addTupleToQueue)                                202.0                    [retiring 53.17%]                                                 0.112526      0.105445  0.004398  0.002598
# 16  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, whichCellTuple)                                 95.0                     [retiring 53.11%]                                                 0.112481      0.105307  0.004418  0.002715
# 91  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell, whichCellTuple)                                     47.0                     [retiring 62.62%]                                                 0.024334      0.016665  0.006505  0.000724
# 27  (main, initMC, initMesh, buildMeshPartition, buildCellIndexMap, exchange, cellInfoMpiType)                                       45.0                     [backend_bound 58.69%, core_bound 43.09%]                         0.000000     -0.042341 -0.000692  0.012955
# 54  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, whichCell, tupleToIndex)                                       43.0                     [retiring 63.13%]                                                 0.022996      0.017873  0.004670  0.000453
# 52  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, addTupleToQueue)                171.0                    [retiring 53.66%]                                                 0.112044      0.105458  0.004230  0.002261
# 21  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addTupleToQueue, tupleToIndex)                  148.0                    [retiring 53.17%]                                                 0.111637      0.104760  0.004543  0.002258
# 62  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, indexToTuple)                   147.0                    [retiring 53.65%]                                                 0.111459      0.105273  0.004103  0.002010
# 26  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2, whichCellTuple)                       99.0                     [retiring 53.38%]                                                 0.112407      0.105567  0.004236  0.002548
# 14  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, minDist2, indexToTuple)                         48.0                     [retiring 53.62%]                                                 0.112065      0.105379  0.004169  0.002439
# 50  (main, initMC, initMesh, buildMeshPartition, assignCellsToDomain, nearestCenter, addNbrsToQueue, addTupleToQueue, tupleToIndex)  79.0                     [retiring 53.75%]                                                 0.111491      0.105106  0.004113  0.002175

# %% [markdown]
# ## Investigate the Hot Path

# %%
tree = hatchet.Tree(mrt.roots[0])
tree.hot_path('time.inclusive.duration')
# Out:
#    ...
# 0  ...
# 10 ...
# 28 ...
#
# [3 rows x 22 columns]

# %% [markdown]
# ## Find All Core-Bound Functions

# %%
dfb['core_bound'] = dfb['boundedness'].transform(lambda l: any('core_bound' in s for s in l))
dfb[dfb['core_bound']].sort_values('time.inclusive.duration', ascending=False)
# Out:
#    ...
# 9  ...
# 63 ...
# 66 ...
# 17 ...
# 33 ...
# 42 ...
# 11 ...
# 45 ...
# 14 ...
# 28 ...
# 3  ...
# 25 ...
# 27 ...
# 25 ...
# 34 ...
# 59 ...
# 38 ...
#
# [17 rows x 22 columns]
